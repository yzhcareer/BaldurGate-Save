# %%
import os
import sys
import re
import pandas as pd
import mmap
from enum import Enum
from IPython.display import display

# %%
F1 = '/Users/CIDER/工作/Python程序/游戏/博德之门/000000001-Quick-Save-4.bg1save'
F2 = '/Users/CIDER/工作/Python程序/游戏/博德之门/000000001-Quick-Save-3.bg1save'
F3 = '/Users/CIDER/工作/Python程序/游戏/博德之门/000000001-Quick-Save-2.bg1save'
F4 = '/Users/CIDER/工作/Python程序/游戏/博德之门/000000001-Quick-Save.bg1save'

# %%
def f(s):
    result = dict()
    for i in s.split('\n'):
        if not i:
            continue
        _i = i.split()
        if re.match('0x[0-9a-fA-F]+', _i[0]):
            result[_i[1]] = int(_i[0], 16)
    return result

def f2(d, l=1):
    for k, v in sorted(d.items(), key=lambda x: x[1]):
        print (k, '=' , ('0x{0:0' + str(l) + 'X}').format(v))

# %%
class Table:
    
    class Class(Enum):
        MAGE = 0x01
        FIGHTER = 0x02
        CLERIC = 0x03
        THIEF = 0x04
        BARD = 0x05
        PALADIN = 0x06
        FIGHTER_MAGE = 0x07
        FIGHTER_CLERIC = 0x08
        FIGHTER_THIEF = 0x09
        FIGHTER_MAGE_THIEF = 0x0A
        DRUID = 0x0B
        RANGER = 0x0C
        MAGE_THIEF = 0x0D
        CLERIC_MAGE = 0x0E
        CLERIC_THIEF = 0x0F
        FIGHTER_DRUID = 0x10
        FIGHTER_MAGE_CLERIC = 0x11
        CLERIC_RANGER = 0x12
        SORCERER = 0x13
        MONK = 0x14
        ANKHEG = 0x65
        BASILISK = 0x66
        BASILISK_GREATER = 0x67
        BEAR_BLACK = 0x68
        BEAR_BROWN = 0x69
        BEAR_CAVE = 0x6A
        BEAR_POLAR = 0x6B
        CARRIONCRAWLER = 0x6C
        DOG_WILD = 0x6D
        DOG_WAR = 0x6E
        DOPPLEGANGER = 0x6F
        DOPPLEGANGER_GREATER = 0x70
        DRIZZT = 0x71
        ELMINSTER = 0x72
        ETTERCAP = 0x73
        GHOUL = 0x74
        GHOUL_REVEANT = 0x75
        GHOUL_GHAST = 0x76
        GIBBERLING = 0x77
        GNOLL = 0x78
        HOBGOBLIN = 0x79
        KOBOLD = 0x7A
        KOBOLD_TASLOI = 0x7B
        KOBOLD_XVART = 0x7C
        OGRE = 0x7D
        OGRE_MAGE = 0x7E
        OGRE_HALFOGRE = 0x7F
        OGRE_OGRILLON = 0x80
        SAREVOK = 0x81
        FAIRY_SIRINE = 0x82
        FAIRY_DRYAD = 0x83
        FAIRY_NEREID = 0x84
        FAIRY_NYMPH = 0x85
        SKELETON = 0x86
        SKELETON_WARRIOR = 0x87
        SKELETON_BANEGUARD = 0x88
        SPIDER_GIANT = 0x89
        SPIDER_HUGE = 0x8A
        SPIDER_PHASE = 0x8B
        SPIDER_SWORD = 0x8C
        SPIDER_WRAITH = 0x8D
        VOLO = 0x8E
        WOLF = 0x8F
        WOLF_WORG = 0x90
        WOLF_DIRE = 0x91
        WOLF_WINTER = 0x92
        WOLF_VAMPIRIC = 0x93
        WOLF_DREAD = 0x94
        WYVERN = 0x95
        OLIVE_SLIME = 0x96
        MUSTARD_JELLY = 0x97
        OCRE_JELLY = 0x98
        GREY_OOZE = 0x99
        GREEN_SLIME = 0x9A
        INNOCENT = 0x9B
        FLAMING_FIST = 0x9C
        WEREWOLF = 0x9D
        WOLFWERE = 0x9E
        DEATHKNIGHT = 0x9F
        TANARI = 0xA0
        BEHOLDER = 0xA1
        MIND_FLAYER = 0xA2
        VAMPIRE = 0xA3
        VAMPYRE = 0xA4
        OTYUGH = 0xA5
        RAKSHASA = 0xA6
        TROLL = 0xA7
        UMBERHULK = 0xA8
        SAHUAGIN = 0xA9
        SHADOW = 0xAA
        SPECTRE = 0xAB
        WRAITH = 0xAC
        KUO_TOA = 0xAD
        MIST = 0xAE
        CAT = 0xAF
        DUERGAR = 0xB0
        MEPHIT = 0xB1
        MIMIC = 0xB2
        IMP = 0xB3
        GIANT = 0xB4
        ORC = 0xB5
        GOLEM_IRON = 0xB6
        GOLEM_FLESH = 0xB7
        GOLEM_STONE = 0xB8
        GOLEM_CLAY = 0xB9
        ELEMENTAL_AIR = 0xBA
        ELEMENTAL_FIRE = 0xBB
        ELEMENTAL_EARTH = 0xBC
        SPIDER_CENTEOL = 0xBD
        RED_DRAGON = 0xBE
        SHADOW_DRAGON = 0xBF
        SILVER_DRAGON = 0xC0
        GENIE_DJINNI = 0xC1
        GENIE_DAO = 0xC2
        GENIE_EFREETI = 0xC3
        GENIE_NOBLE_DJINNI = 0xC4
        GENIE_NOBLE_EFREETI = 0xC5
        ZOMBIE_NORMAL = 0xC6
        FOOD_CREATURE = 0xC7
        HUNTER_CREATURE = 0xC8
        LONG_SWORD = 0xC9
        LONG_BOW = 0xCA
        MAGE_ALL = 0xCA
        FIGHTER_ALL = 0xCB
        CLERIC_ALL = 0xCC
        THIEF_ALL = 0xCD
        BARD_ALL = 0xCE
        PALADIN_ALL = 0xCF
        DRUID_ALL = 0xD0
        RANGER_ALL = 0xD1
        WIZARD_EYE = 0xD2
        CANDLEKEEP_WATCHER = 0xD3
        AMNISH_SOLDIER = 0xD4
        TOWN_GUARD = 0xD5
        NO_CLASS = 0xFF
        
    class Alignment(Enum):
        NONE = 0x00
        MASK_GOOD = 0x01
        MASK_GENEUTRAL = 0x02
        MASK_EVIL = 0x03
        MASK_LAWFUL = 0x10
        LAWFUL_GOOD = 0x11
        LAWFUL_NEUTRAL = 0x12
        LAWFUL_EVIL = 0x13
        MASK_LCNEUTRAL = 0x20
        NEUTRAL_GOOD = 0x21
        NEUTRAL = 0x22
        NEUTRAL_EVIL = 0x23
        MASK_CHAOTIC = 0x30
        CHAOTIC_GOOD = 0x31
        CHAOTIC_NEUTRAL = 0x32
        CHAOTIC_EVIL = 0x33
        
    class Gender(Enum):
        MALE = 0x01
        FEMALE = 0x02
        OTHER = 0x03
        NIETHER = 0x04
        BOTH = 0x05
        SUMMONED = 0x06
        ILLUSIONARY = 0x07
        EXTRA = 0x08
        SUMMONED_DEMON = 0x09
        
    class Race(Enum):
        NONE = 0
        HUMAN = 0x01
        ELF = 0x02
        HALF_ELF = 0x03
        DWARF = 0x04
        HALFLING = 0x05
        GNOME = 0x06
        HALFORC = 0x07
        ANKHEG = 0x65
        BASILISK = 0x66
        BEAR = 0x67
        CARRIONCRAWLER = 0x68
        DOG = 0x69
        DOPPLEGANGER = 0x6A
        ETTERCAP = 0x6B
        GHOUL = 0x6C
        GIBBERLING = 0x6D
        GNOLL = 0x6E
        HOBGOBLIN = 0x6F
        KOBOLD = 0x70
        OGRE = 0x71
        SKELETON = 0x73
        SPIDER = 0x74
        WOLF = 0x75
        WYVERN = 0x76
        SLIME = 0x77
        FAIRY = 0x78
        DEMONIC = 0x79
        LYCANTHROPE = 0x7A
        BEHOLDER = 0x7B
        MIND_FLAYER = 0x7C
        VAMPIRE = 0x7D
        VAMPYRE = 0x7E
        OTYUGH = 0x7F
        RAKSHASA = 0x80
        TROLL = 0x81
        UMBERHULK = 0x82
        SAHUAGIN = 0x83
        SPECTRE = 0x85
        WRAITH = 0x86
        KUO_TOA = 0x87
        MIST = 0x88
        CAT = 0x89
        DUERGAR = 0x8A
        MEPHIT = 0x8B
        MIMIC = 0x8C
        IMP = 0x8D
        GIANT = 0x8E
        ORC = 0x8F
        GOLEM = 0x90
        ELEMENTAL = 0x91
        DRAGON = 0x92
        GENIE = 0x93
        ZOMBIE = 0x94
        SHADOW = 0x95
        LICH = 0x96
        RABBIT = 0x97
        GITHYANKI = 0x98
        TIEFLING = 0x99
        YUANTI = 0x9A
        DEMILICH = 0x9B
        SOLAR = 0x9C
        ANTISOLAR = 0x9D
        PLANATAR = 0x9E
        DARKPLANATAR = 0x9F
        SWORD = 0xC9
        BOW = 0xCA
        XBOW = 0xCB
        STAFF = 0xCC
        SLING = 0xCD
        MACE = 0xCE
        DAGGER = 0xCF
        SPEAR = 0xD0
        FIST = 0xD1
        HAMMER = 0xD2
        MORNINGSTAR = 0xD3
        ROBES = 0xD4
        LEATHER = 0xD5
        CHAIN = 0xD6
        PLATE = 0xD7
        NO_RACE = 0xFF
        
    class State(Enum):
        STATE_NORMAL = 0x0000
        STATE_SLEEPING = 0x0001
        STATE_BERSERK = 0x0002
        STATE_PANIC = 0x0004
        STATE_STUNNED = 0x0008
        STATE_INVISIBLE = 0x0010
        STATE_HELPLESS = 0x0020
        STATE_IMMOBILE = 0x0029
        STATE_FROZEN_DEATH = 0x0040
        STATE_STONE_DEATH = 0x0080
        STATE_EXPLODING_DEATH = 0x0100
        STATE_FLAME_DEATH = 0x0200
        STATE_ACID_DEATH = 0x0400
        STATE_DEAD = 0x0800
        STATE_REALLY_DEAD = 0x0FC0
        STATE_SILENCED = 0x1000
        STATE_CHARMED = 0x2000
        STATE_POISONED = 0x4000
        STATE_HASTED = 0x8000
        STATE_SLOWED = 0x10000
        STATE_INFRAVISION = 0x20000
        STATE_BLIND = 0x40000
        STATE_DISEASED = 0x80000
        STATE_FEEBLEMINDED = 0x100000
        STATE_HARMLESS = 0x102029
        STATE_NONDETECTION = 0x200000
        STATE_IMPROVEDINVISIBILITY = 0x400000
        STATE_NOT_TARGETABLE = 0x400010
        STATE_BLESS = 0x800000
        STATE_CHANT = 0x1000000
        STATE_DRAWUPONHOLYMIGHT = 0x2000000
        STATE_LUCK = 0x4000000
        STATE_AID = 0x8000000
        STATE_CHANTBAD = 0x10000000
        STATE_BLUR = 0x20000000
        STATE_MIRRORIMAGE = 0x40000000
        STATE_ILLUSIONS = 0x60400010
        STATE_CONFUSED = 0x80000000
        STATE_NOT_APPROACHABLE = 0x80002006
        STATE_RANGED_TARGET = 0x80040004
        CD_STATE_NOTVALID = 0x80101FEF
        STATE_DISABLED = 0x8010202D
        STATE_DISABLED_CASTING = 0x8010302D
        STATE_DEBUFF = 0x8015302D
        
    class Kit(Enum):
        MAGESCHOOL_ABJURER = 0x0040
        MAGESCHOOL_CONJURER = 0x0080
        MAGESCHOOL_DIVINER = 0x0100
        MAGESCHOOL_ENCHANTER = 0x0200
        MAGESCHOOL_ILLUSIONIST = 0x0400
        MAGESCHOOL_INVOKER = 0x0800
        MAGESCHOOL_NECROMANCER = 0x1000
        MAGESCHOOL_TRANSMUTER = 0x2000
        TRUECLASS = 0x4000
        MAGESCHOOL_GENERALIST = 0x4000
        BERSERKER = 0x4001
        WIZARDSLAYER = 0x4002
        KENSAI = 0x4003
        CAVALIER = 0x4004
        INQUISITOR = 0x4005
        UNDEADHUNTER = 0x4006
        FERALAN = 0x4007
        STALKER = 0x4008
        BEASTMASTER = 0x4009
        ASSASIN = 0x400A
        BOUNTYHUNTER = 0x400B
        SWASHBUCKLER = 0x400C
        BLADE = 0x400D
        JESTER = 0x400E
        SKALD = 0x400F
        TOTEMIC = 0x4010
        SHAPESHIFTER = 0x4011
        BEASTFRIEND = 0x4012
        GODTALOS = 0x4013
        GODHELM = 0x4014
        GODLATHANDER = 0x4015
        BLACKGUARD = 0x4020
        SHADOWDANCER = 0x4021
        DWARVEN_DEFENDER = 0x4022
        DRAGON_DISCIPLE = 0x4023
        DARK_MOON = 0x4024
        SUN_SOUL = 0x4025
        GRIZZLY_BEAR = 0x4027
        OHTYR = 0x4028
        BARBARIAN = 0x40000000
        WILDMAGE = 0x80000000

# %%
class Segments(Enum):
    States = (0x0020, 4, 'State', None)
    MaxHP = (0x0024, 2, None, 100)
    CurrentHP = (0x0026, 2, None, 100)
    HideInShadow = (0x0045, 1, None, 100)
    NatureAC = (0x0046, 2, None, 0)
    EffectiveAC = (0x0048, 2, None, 0)
    CrushAC = (0x004A, 2, None, 20)
    MissileAC = (0x004C, 2, None, 20)
    PiercingAC = (0x004E, 2, None, 20)
    SlashingAC = (0x0050, 2, None, 20)
    THAC0 = (0x0052, 1, None, 0)
    NumOfAttack = (0x0053, 1, None, 5)
    SaveVsDeath = (0x0054, 1, None, 20)
    SaveVsWands = (0x0055, 1, None, 20)
    SaveVsPolymorph = (0x0056, 1, None, 20)
    SaveVsBreath = (0x0057, 1, None, 20)
    SaveVsSpell = (0x0058, 1, None, 20)
    ResistFire = (0x0059, 1, None, 20)
    ResistCold = (0x005A, 1, None, 20)
    ResistElectricity = (0x005B, 1, None, 20)
    ResistAcid = (0x005C, 1, None, 20)
    ResistMagic = (0x005D, 1, None, 20)
    ResistMagicFire = (0x005E, 1, None, 20)
    ResistMagicCold = (0x005F, 1, None, 20)
    ResistSlashing = (0x0060, 1, None, 20)
    ResistCrushing = (0x0061, 1, None, 20)
    ResistPiercing = (0x0062, 1, None, 20)
    ResistMissile = (0x0063, 1, None, 20)
    DetectIllusion = (0x0064, 1, None, 100)
    SetTraps = (0x0065, 1, None, 100)
    Lore = (0x0066, 1, None, 100)
    Lockpicking = (0x0067, 1, None, 100)
    Stealth = (0x0068, 1, None, 100)
    FindTraps = (0x0069, 1, None, 100)
    PickPockets = (0x006A, 1, None, 100)
    Fatigue = (0x006B, 1, None, 0)
    Intoxication = (0x006C, 1, None, 0)
    Luck = (0x006D, 1, None, 100)
    TurnUndead = (0x0082, 1, None, 100)
    Tracking = (0x0083, 1, None, 100)
    LvClass1 = (0x0234, 1, None, 0)
    LvClass2 = (0x0235, 1, None, 0)
    LvClass3 = (0x0236, 1, None, 0)
    Sex = (0x0237, 1, 'Gender', None)
    Strength = (0x0238, 1, None, 25)
    StrBonus = (0x0239, 1, None, 0)
    Intelligence = (0x023A, 1, None, 25)
    Wisdom = (0x023B, 1, None, 25)
    Dexterity = (0x023C, 1, None, 25)
    Constitution = (0x023D, 1, None, 25)
    Charisma = (0x023E, 1, None, 25)
    Morale = (0x023F, 1, None, 100)
    MoraleBreak = (0x0240, 1, None, 0)
    RacialEnemy = (0x0241, 1, 'Race', None)
    Kit = (0x0244, 4, 'Kit', None)
    Race = (0x0272, 1, 'Race', None)
    Class = (0x0273, 1, 'Class', None)
    Gender = (0x0275, 1, 'Gender', None)
    Alignment = (0x027B, 1, 'Alignment', None)
    
    @property
    def offset(self):
        return self.value[0]
    
    @property
    def length(self):
        return self.value[1]
    
    @property
    def table(self):
        return self.value[2]
    
    @property
    def goodValue(self):
        return self.value[4]

# %%
class CRE:

    def __init__(self, buffer, name, cre_offset, cre_length):
        self.name = name
        self.extra_offset = -10
        self.cre_offset = cre_offset - self.extra_offset
        self.cre_length = cre_length
        self.buffer = buffer
        self.raw_data = list(self.buffer[cre_offset: cre_offset + cre_length])
        self.data = pd.DataFrame()
        
    @staticmethod
    def bytes2Num(barray):
        return int.from_bytes(barray, 'little')
    
    @staticmethod
    def num2Bytes(num, length):
        return num.to_bytes(length, 'little')
    
    def save(self):
        self.buffer.flush()
        
    
    def setValue(self, item, value):
        _item = item.name
        _seg = Segments[_item]
        if isinstance(value, int):
            _value = value
        else:
            _value = value.value
        _offset = _seg.offset + self.cre_offset
        self.buffer[_offset: _offset + _seg.length] = self.num2Bytes(_value, _seg.length)
            
            
    def optimize(self):
        for _item, _seg in Segments.__members__.items():
            _offset = _seg.offset + self.cre_offset
            if _seg.goodValue is not None:
                self.buffer[_offset: _offset + _seg.length] = self.num2Bytes(_seg.goodValue, _seg.length)
    
    
    @staticmethod
    def checkTable(table, number):
        if not table:
            return str(int(number))
        else:
            return getattr(Table, table)(number).name
                
        
    def read(self):
        self.data = pd.DataFrame()
        for _item, _seg in Segments.__members__.items():
            _offset = _seg.offset + self.cre_offset
            _number = self.bytes2Num(self.buffer[_offset:_offset + _seg.length])
            try:
                _value = self.checkTable(_seg.table, _number)
            except ValueError:
                _value = '0x{0:8X}'.format(_number)
            self.data = self.data.append({'segment': _seg.name,
                                          'file_offset': '0x{0:06X}h'.format(_offset),
                                          'CRE_offset': '0x{0:06X}h'.format(_seg.offset),
                                          'length': _seg.length,
                                          'number': _number,
                                          'value': _value},
                                         ignore_index=True)
        self.data['length'] = self.data['length'].astype(int)
        self.data['number'] = self.data['number'].astype(int)
        self.data.set_index('segment', inplace=True)
        self.data.index.name=None

# %%
class SaveFile:
    
    headseg_len = 352
    headseg_offset = [194, 198, 382]
    cre_string = [ord(_) for _ in 'CRE V1.0'] + [0xFF] * 8
    save_string = [ord(_) for _ in 'BALDUR.gamGAMEV2.0']

    
    def __init__(self, filename):
        self.pwd = os.path.dirname(filename)
        self.file = os.path.basename(filename)
        with open(filename, 'rb+') as _f:
            self.buffer = mmap.mmap(_f.fileno(), 0)
        self.contents = list(self.buffer.read())
        self.buffer.seek(0)
        self.length = len(self.contents)
        self.save_offset = self.search(self.save_string)[0]
        self.cre_offsets = self.search(self.cre_string)
        self.cre_counts = self.contents[self.save_offset + 0x2e]
        self.cre = list()
        self.readCRE()
        self.data = pd.DataFrame()
        self.buildTable()
    
    @staticmethod
    def string2Dict(s, lead='number', base=16):
        result = dict()
        for i in s.split('\n'):
            if not i:
                continue
            _i = i.split()
            if lead != 'number':
                _i = _i[::-1]
            if re.match('0x[0-9a-fA-F]+', _i[0]):
                result[_i[1]] = int(_i[0], base)
        return result

    @staticmethod
    def dict2Enum(d, byte=1):
        for k, v in sorted(d.items(), key=lambda x: x[1]):
            print (k, '=' , ('0x{0:0' + str(byte) + 'X}').format(v))
        
    def readCRE(self):
        for i in range(self.cre_counts):
            _offset = self.save_offset + i * self.headseg_len + self.headseg_offset[0]
            _len = self.save_offset + i * self.headseg_len + self.headseg_offset[1]
            _name = self.save_offset + i * self.headseg_len + self.headseg_offset[2]
            self.cre.append(CRE(self.buffer,
                                self.readContinuousString(_name),
                                self.save_offset + self.bytes2Num(self.contents[_offset: _offset + 2]),
                                self.save_offset + self.bytes2Num(self.contents[_len: _len + 2])
                               )
                           )
            self.cre[-1].read()
            
            
    def optimize(self):
        for _cre in self.cre:
            _cre.optimize()
        self.buffer.flush()
        for _cre in self.cre:
            _cre.read()
                   
    
    def search(self, flag):
        results = list()
        _l = len(flag)
        for i in range(self.length - _l):
            if self.contents[i: i+_l] == flag:
                results.append(i)
        return results
            
    
    @staticmethod
    def bytes2Num(b):
        result = 0
        for i in b[::-1]:
            result = result * 256 + i
        return result
    
    def readContinuousString(self, offset):
        i = 0
        while re.match('[a-zA-Z0-9-\.]', chr(self.contents[offset+i])):
            i += 1
        return ''.join([chr(_) for _ in self.contents[offset:offset+i]])


    def buildTable(self):
        self.data = pd.concat([_.data['value'] for _ in self.cre], axis=1)
        self.data.columns = [_.name for _ in self.cre]

# %%
t1 = SaveFile(F1)

# %%
t1.data
# Out:
#                                q             w             e             r  \
# States              STATE_NORMAL  STATE_NORMAL  STATE_NORMAL  STATE_NORMAL
# MaxHP                         10            10            10            10
# CurrentHP                     10            10            10            10
# HideInShadow                   0             0             0             0
# NatureAC                      10            10            10            10
# EffectiveAC                   10            10            10            10
# CrushAC                        0             0             0             0
# MissileAC                      0             0             0             0
# PiercingAC                     0             0             0             0
# SlashingAC                     0             0             0             0
# THAC0                         20            20            20            20
# ...

# %%
t1.cre[0].setValue(Segments.Class, Table.Class.CLERIC_RANGER)
t1.cre[0].setValue(Segments.Lockpicking, 150)

# %%
t1.cre[0].read()

# %%
t1.data
# Out:
#                                q             w             e             r  \
# States              STATE_NORMAL  STATE_NORMAL  STATE_NORMAL  STATE_NORMAL
# MaxHP                         10            10            10            10
# CurrentHP                     10            10            10            10
# HideInShadow                   0             0             0             0
# NatureAC                      10            10            10            10
# EffectiveAC                   10            10            10            10
# CrushAC                        0             0             0             0
# MissileAC                      0             0             0             0
# PiercingAC                     0             0             0             0
# SlashingAC                     0             0             0             0
# THAC0                         20            20            20            20
# ...
