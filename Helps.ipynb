# %%
from enum import Enum

class Tables:
    
    class Class(Enum):
        MAGE = 0x01
        FIGHTER = 0x02
        CLERIC = 0x03
        THIEF = 0x04
        BARD = 0x05
        PALADIN = 0x06
        FIGHTER_MAGE = 0x07
        FIGHTER_CLERIC = 0x08
        FIGHTER_THIEF = 0x09
        FIGHTER_MAGE_THIEF = 0x0A
        DRUID = 0x0B
        RANGER = 0x0C
        MAGE_THIEF = 0x0D
        CLERIC_MAGE = 0x0E
        CLERIC_THIEF = 0x0F
        FIGHTER_DRUID = 0x10
        FIGHTER_MAGE_CLERIC = 0x11
        CLERIC_RANGER = 0x12
        SORCERER = 0x13
        MONK = 0x14
        ANKHEG = 0x65
        BASILISK = 0x66
        BASILISK_GREATER = 0x67
        BEAR_BLACK = 0x68
        BEAR_BROWN = 0x69
        BEAR_CAVE = 0x6A
        BEAR_POLAR = 0x6B
        CARRIONCRAWLER = 0x6C
        DOG_WILD = 0x6D
        DOG_WAR = 0x6E
        DOPPLEGANGER = 0x6F
        DOPPLEGANGER_GREATER = 0x70
        DRIZZT = 0x71
        ELMINSTER = 0x72
        ETTERCAP = 0x73
        GHOUL = 0x74
        GHOUL_REVEANT = 0x75
        GHOUL_GHAST = 0x76
        GIBBERLING = 0x77
        GNOLL = 0x78
        HOBGOBLIN = 0x79
        KOBOLD = 0x7A
        KOBOLD_TASLOI = 0x7B
        KOBOLD_XVART = 0x7C
        OGRE = 0x7D
        OGRE_MAGE = 0x7E
        OGRE_HALFOGRE = 0x7F
        OGRE_OGRILLON = 0x80
        SAREVOK = 0x81
        FAIRY_SIRINE = 0x82
        FAIRY_DRYAD = 0x83
        FAIRY_NEREID = 0x84
        FAIRY_NYMPH = 0x85
        SKELETON = 0x86
        SKELETON_WARRIOR = 0x87
        SKELETON_BANEGUARD = 0x88
        SPIDER_GIANT = 0x89
        SPIDER_HUGE = 0x8A
        SPIDER_PHASE = 0x8B
        SPIDER_SWORD = 0x8C
        SPIDER_WRAITH = 0x8D
        VOLO = 0x8E
        WOLF = 0x8F
        WOLF_WORG = 0x90
        WOLF_DIRE = 0x91
        WOLF_WINTER = 0x92
        WOLF_VAMPIRIC = 0x93
        WOLF_DREAD = 0x94
        WYVERN = 0x95
        OLIVE_SLIME = 0x96
        MUSTARD_JELLY = 0x97
        OCRE_JELLY = 0x98
        GREY_OOZE = 0x99
        GREEN_SLIME = 0x9A
        INNOCENT = 0x9B
        FLAMING_FIST = 0x9C
        WEREWOLF = 0x9D
        WOLFWERE = 0x9E
        DEATHKNIGHT = 0x9F
        TANARI = 0xA0
        BEHOLDER = 0xA1
        MIND_FLAYER = 0xA2
        VAMPIRE = 0xA3
        VAMPYRE = 0xA4
        OTYUGH = 0xA5
        RAKSHASA = 0xA6
        TROLL = 0xA7
        UMBERHULK = 0xA8
        SAHUAGIN = 0xA9
        SHADOW = 0xAA
        SPECTRE = 0xAB
        WRAITH = 0xAC
        KUO_TOA = 0xAD
        MIST = 0xAE
        CAT = 0xAF
        DUERGAR = 0xB0
        MEPHIT = 0xB1
        MIMIC = 0xB2
        IMP = 0xB3
        GIANT = 0xB4
        ORC = 0xB5
        GOLEM_IRON = 0xB6
        GOLEM_FLESH = 0xB7
        GOLEM_STONE = 0xB8
        GOLEM_CLAY = 0xB9
        ELEMENTAL_AIR = 0xBA
        ELEMENTAL_FIRE = 0xBB
        ELEMENTAL_EARTH = 0xBC
        SPIDER_CENTEOL = 0xBD
        RED_DRAGON = 0xBE
        SHADOW_DRAGON = 0xBF
        SILVER_DRAGON = 0xC0
        GENIE_DJINNI = 0xC1
        GENIE_DAO = 0xC2
        GENIE_EFREETI = 0xC3
        GENIE_NOBLE_DJINNI = 0xC4
        GENIE_NOBLE_EFREETI = 0xC5
        ZOMBIE_NORMAL = 0xC6
        FOOD_CREATURE = 0xC7
        HUNTER_CREATURE = 0xC8
        LONG_SWORD = 0xC9
        LONG_BOW = 0xCA
        MAGE_ALL = 0xCA
        FIGHTER_ALL = 0xCB
        CLERIC_ALL = 0xCC
        THIEF_ALL = 0xCD
        BARD_ALL = 0xCE
        PALADIN_ALL = 0xCF
        DRUID_ALL = 0xD0
        RANGER_ALL = 0xD1
        WIZARD_EYE = 0xD2
        CANDLEKEEP_WATCHER = 0xD3
        AMNISH_SOLDIER = 0xD4
        TOWN_GUARD = 0xD5
        NO_CLASS = 0xFF
        
    class Alignment(Enum):
        NONE = 0x00
        MASK_GOOD = 0x01
        MASK_GENEUTRAL = 0x02
        MASK_EVIL = 0x03
        MASK_LAWFUL = 0x10
        LAWFUL_GOOD = 0x11
        LAWFUL_NEUTRAL = 0x12
        LAWFUL_EVIL = 0x13
        MASK_LCNEUTRAL = 0x20
        NEUTRAL_GOOD = 0x21
        NEUTRAL = 0x22
        NEUTRAL_EVIL = 0x23
        MASK_CHAOTIC = 0x30
        CHAOTIC_GOOD = 0x31
        CHAOTIC_NEUTRAL = 0x32
        CHAOTIC_EVIL = 0x33
        
    class Gender(Enum):
        MALE = 0x01
        FEMALE = 0x02
        OTHER = 0x03
        NIETHER = 0x04
        BOTH = 0x05
        SUMMONED = 0x06
        ILLUSIONARY = 0x07
        EXTRA = 0x08
        SUMMONED_DEMON = 0x09
        
    class Race(Enum):
        NONE = 0
        HUMAN = 0x01
        ELF = 0x02
        HALF_ELF = 0x03
        DWARF = 0x04
        HALFLING = 0x05
        GNOME = 0x06
        HALFORC = 0x07
        ANKHEG = 0x65
        BASILISK = 0x66
        BEAR = 0x67
        CARRIONCRAWLER = 0x68
        DOG = 0x69
        DOPPLEGANGER = 0x6A
        ETTERCAP = 0x6B
        GHOUL = 0x6C
        GIBBERLING = 0x6D
        GNOLL = 0x6E
        HOBGOBLIN = 0x6F
        KOBOLD = 0x70
        OGRE = 0x71
        SKELETON = 0x73
        SPIDER = 0x74
        WOLF = 0x75
        WYVERN = 0x76
        SLIME = 0x77
        FAIRY = 0x78
        DEMONIC = 0x79
        LYCANTHROPE = 0x7A
        BEHOLDER = 0x7B
        MIND_FLAYER = 0x7C
        VAMPIRE = 0x7D
        VAMPYRE = 0x7E
        OTYUGH = 0x7F
        RAKSHASA = 0x80
        TROLL = 0x81
        UMBERHULK = 0x82
        SAHUAGIN = 0x83
        SPECTRE = 0x85
        WRAITH = 0x86
        KUO_TOA = 0x87
        MIST = 0x88
        CAT = 0x89
        DUERGAR = 0x8A
        MEPHIT = 0x8B
        MIMIC = 0x8C
        IMP = 0x8D
        GIANT = 0x8E
        ORC = 0x8F
        GOLEM = 0x90
        ELEMENTAL = 0x91
        DRAGON = 0x92
        GENIE = 0x93
        ZOMBIE = 0x94
        SHADOW = 0x95
        LICH = 0x96
        RABBIT = 0x97
        GITHYANKI = 0x98
        TIEFLING = 0x99
        YUANTI = 0x9A
        DEMILICH = 0x9B
        SOLAR = 0x9C
        ANTISOLAR = 0x9D
        PLANATAR = 0x9E
        DARKPLANATAR = 0x9F
        SWORD = 0xC9
        BOW = 0xCA
        XBOW = 0xCB
        STAFF = 0xCC
        SLING = 0xCD
        MACE = 0xCE
        DAGGER = 0xCF
        SPEAR = 0xD0
        FIST = 0xD1
        HAMMER = 0xD2
        MORNINGSTAR = 0xD3
        ROBES = 0xD4
        LEATHER = 0xD5
        CHAIN = 0xD6
        PLATE = 0xD7
        NO_RACE = 0xFF
        
    class State(Enum):
        STATE_NORMAL = 0x0000
        STATE_SLEEPING = 0x0001
        STATE_BERSERK = 0x0002
        STATE_PANIC = 0x0004
        STATE_STUNNED = 0x0008
        STATE_INVISIBLE = 0x0010
        STATE_HELPLESS = 0x0020
        STATE_IMMOBILE = 0x0029
        STATE_FROZEN_DEATH = 0x0040
        STATE_STONE_DEATH = 0x0080
        STATE_EXPLODING_DEATH = 0x0100
        STATE_FLAME_DEATH = 0x0200
        STATE_ACID_DEATH = 0x0400
        STATE_DEAD = 0x0800
        STATE_REALLY_DEAD = 0x0FC0
        STATE_SILENCED = 0x1000
        STATE_CHARMED = 0x2000
        STATE_POISONED = 0x4000
        STATE_HASTED = 0x8000
        STATE_SLOWED = 0x10000
        STATE_INFRAVISION = 0x20000
        STATE_BLIND = 0x40000
        STATE_DISEASED = 0x80000
        STATE_FEEBLEMINDED = 0x100000
        STATE_HARMLESS = 0x102029
        STATE_NONDETECTION = 0x200000
        STATE_IMPROVEDINVISIBILITY = 0x400000
        STATE_NOT_TARGETABLE = 0x400010
        STATE_BLESS = 0x800000
        STATE_CHANT = 0x1000000
        STATE_DRAWUPONHOLYMIGHT = 0x2000000
        STATE_LUCK = 0x4000000
        STATE_AID = 0x8000000
        STATE_CHANTBAD = 0x10000000
        STATE_BLUR = 0x20000000
        STATE_MIRRORIMAGE = 0x40000000
        STATE_ILLUSIONS = 0x60400010
        STATE_CONFUSED = 0x80000000
        STATE_NOT_APPROACHABLE = 0x80002006
        STATE_RANGED_TARGET = 0x80040004
        CD_STATE_NOTVALID = 0x80101FEF
        STATE_DISABLED = 0x8010202D
        STATE_DISABLED_CASTING = 0x8010302D
        STATE_DEBUFF = 0x8015302D
        
    class Kit(Enum):
        NONE = 0x00000000
        BARBARIAN = 0x00004000
        MAGESCHOOL_WILDMAGE = 0x00008000
        MAGESCHOOL_ABJURER = 0x00400000
        MAGESCHOOL_CONJURER = 0x00800000
        MAGESCHOOL_DIVINER = 0x01000000
        MAGESCHOOL_ENCHANTER = 0x02000000
        MAGESCHOOL_ILLUSIONIST = 0x04000000
        MAGESCHOOL_INVOKER = 0x08000000
        MAGESCHOOL_NECROMANCER = 0x10000000
        MAGESCHOOL_TRANSMUTER = 0x20000000
        TRUECLASS = 0x40000000
        MAGESCHOOL_GENERALIST = 0x40000000
        BERSERKER = 0x40010000
        WIZARDSLAYER = 0x40020000
        KENSAI = 0x40030000
        CAVALIER = 0x40040000
        INQUISITOR = 0x40050000
        UNDEADHUNTER = 0x40060000
        FERALAN = 0x40070000
        STALKER = 0x40080000
        BEASTMASTER = 0x40090000
        ASSASIN = 0x400A0000
        BOUNTYHUNTER = 0x400B0000
        SWASHBUCKLER = 0x400C0000
        BLADE = 0x400D0000
        JESTER = 0x400E0000
        SKALD = 0x400F0000
        TOTEMIC = 0x40100000
        SHAPESHIFTER = 0x40110000
        BEASTFRIEND = 0x40120000
        GODTALOS = 0x40130000
        GODHELM = 0x40140000
        GODLATHANDER = 0x40150000
        BLACKGUARD = 0x40200000
        SHADOWDANCER = 0x40210000
        DWARVEN_DEFENDER = 0x40220000
        DRAGON_DISCIPLE = 0x40230000
        DARK_MOON = 0x40240000
        SUN_SOUL = 0x40250000
        GRIZZLY_BEAR = 0x40270000
        OHTYR = 0x40280000
        
    class Target(Enum):
        NONE = 0
        SELF_PRE = 1
        PRE_TARGET = 2
        PARTY = 3
        EVERYONE_PARTY = 4
        EVERYONE_NOPARTY = 5
        EVERYONE_MATCH_CASTER = 6
        EVERYONE_MATCH_TARGET = 7
        EVERYONE_NOCASTER = 8
        SELF_POST = 9  

    class Time(Enum):
        DURATION = 0
        PERMANENT = 1
        EQUIPPED = 2
        DELAYED_DURATION = 3
        DELAYED = 4
        DELAYED_PERMANENT = 5
        DURATION_2 = 6
        PERMANENT_2 = 7
        PERMANENT_UNSAVED = 8
        PERMANENT_AFTER_DEATH = 9
        TRIGGER = 10
        ABSOLUTE = 4096

    class WeaponType(Enum):
        BastardSword = 89
        LongSword = 90
        ShortSword = 91
        Axe = 92
        TwoHandedSword = 93
        Katana = 94
        ScimitarWakizashiNinjaTo = 95
        Dagger = 96
        WarHammer = 97
        Spear = 98
        Halberd = 99
        FlailMorningstar = 100
        Mace = 101
        QuarterStaff = 102
        Crossbow = 103
        LongBow = 104
        ShortBow = 105
        Darts = 106
        Sling = 107
        #Blackjack = 108
        #Gun = 109
        #MartialArts = 110
        TwoHandedWeaponSkill = 111
        SwordandShieldSkill = 112
        SingleWeaponSkill = 113
        TwoWeaponSkill = 114
        Club = 115
        #ExtraProficiency2 = 116
        #ExtraProficiency3 = 117
        #ExtraProficiency4 = 118
        #ExtraProficiency5 = 119
        #ExtraProficiency6 = 120
        #ExtraProficiency7 = 121
        #ExtraProficiency8 = 122
        #ExtraProficiency9 = 123
        #ExtraProficiency10 = 124
        #ExtraProficiency11 = 125
        #ExtraProficiency12 = 126
        #ExtraProficiency13 = 127
        #ExtraProficiency14 = 128
        #ExtraProficiency15 = 129
        #ExtraProficiency16 = 130
        #ExtraProficiency17 = 131
        #ExtraProficiency18 = 132
        #ExtraProficiency19 = 133
        #ExtraProficiency20 = 134

# %%
class Segments(BaseTable):
    
    Gold = (0x001c, 4, False, 'little', None, 10000)
    States = (0x0020, 4, False, 'little', 'State', None)
    MaxHP = (0x0024, 2, False, 'little', None, 200)
    CurrentHP = (0x0026, 2, False, 'little', None, 200)
    Reputation = (0x0044, 1, True, 'little', None, 20)
    HideInShadow = (0x0045, 1, False, 'little', None, 100)
    NatureAC = (0x0046, 2, True, 'little', None, -10)
    EffectiveAC = (0x0048, 2, True, 'little', None, -10)
    CrushAC = (0x004A, 2, True, 'little', None, -10)
    MissileAC = (0x004C, 2, True, 'little', None, -10)
    PiercingAC = (0x004E, 2, True, 'little', None, -10)
    SlashingAC = (0x0050, 2, True, 'little', None, -10)
    THAC0 = (0x0052, 1, False, 'little', None, 0)
    NumOfAttack = (0x0053, 1, False, 'little', None, 10)
    SaveVsDeath = (0x0054, 1, False, 'little', None, 0)
    SaveVsWands = (0x0055, 1, False, 'little', None, 0)
    SaveVsPolymorph = (0x0056, 1, False, 'little', None, 0)
    SaveVsBreath = (0x0057, 1, False, 'little', None, 0)
    SaveVsSpell = (0x0058, 1, False, 'little', None, 0)
    ResistFire = (0x0059, 1, False, 'little', None, 100)
    ResistCold = (0x005A, 1, False, 'little', None, 100)
    ResistElectricity = (0x005B, 1, False, 'little', None, 100)
    ResistAcid = (0x005C, 1, False, 'little', None, 100)
    ResistMagic = (0x005D, 1, False, 'little', None, 100)
    ResistMagicFire = (0x005E, 1, False, 'little', None, 100)
    ResistMagicCold = (0x005F, 1, False, 'little', None, 100)
    ResistSlashing = (0x0060, 1, False, 'little', None, 100)
    ResistCrushing = (0x0061, 1, False, 'little', None, 100)
    ResistPiercing = (0x0062, 1, False, 'little', None, 100)
    ResistMissile = (0x0063, 1, False, 'little', None, 100)
    DetectIllusion = (0x0064, 1, False, 'little', None, 100)
    SetTraps = (0x0065, 1, False, 'little', None, 100)
    Lore = (0x0066, 1, False,'little',  None, 100)
    Lockpicking = (0x0067, 1, False, 'little', None, 100)
    Stealth = (0x0068, 1,False, 'little',  None, 100)
    FindTraps = (0x0069, 1, False, 'little',None, 100)
    PickPockets = (0x006A, 1, False, 'little', None, 100)
    Fatigue = (0x006B, 1,False, 'little',  None, 0)
    Intoxication = (0x006C, 1, False, 'little', None, 0)
    Luck = (0x006D, 1, False, 'little', None,  100)
    #LSwordPro = (0x006E, 1, False, 'little', None, 5)
    #SSwordPro = (0x006F, 1, False, 'little', None, 5)
    #BowPro = (0x0070, 1, False, 'little', None, 5)
    #SpearPro = (0x0071, 1, False, 'little', None, 5)
    #BluntPro = (0x0072, 1, False, 'little', None, 5)
    #SpikedPro = (0x0073, 1, False, 'little', None, 5)
    #AxePro = (0x0074, 1, False, 'little', None, 5)
    #MissilePro = (0x0075, 1, False, 'little', None, 5)
    #UnusedPro1 = (0x0076, 1, False, 'little', None, 5)
    #UnusedPro2 = (0x0077, 1, False, 'little', None, 5)
    #UnusedPro3 = (0x0078, 1, False, 'little', None, 5)
    #UnusedPro4 = (0x0079, 1, False, 'little', None, 5)
    #UnusedPro5 = (0x007a, 1, False, 'little', None, 5)
    #UnusedPro6 = (0x007b, 1, False, 'little', None, 5)
    #UnusedPro7 = (0x007c, 1, False, 'little', None, 5)
    #NightMareMode = (0x007d, 1, False, 'little', None, None)
    #Translucency = (0x007e, 1, False, 'little', None, None)
    #MurderInc = (0x007f, 1, False, 'little', None, None)
    #ReputationJoin = (0x0080, 1, False, 'little', None, None)
    #ReputationLeave = (0x0081, 1, False, 'little', None, None)
    TurnUndead = (0x0082, 1, False, 'little', None, 100)
    Tracking = (0x0083, 1, False, 'little', None, 100)
    LvClass1 = (0x0234, 1, False, 'little', None, 1)
    LvClass2 = (0x0235, 1, False, 'little', None, 1)
    LvClass3 = (0x0236, 1, False, 'little', None, 1)
    Sex = (0x0237, 1, False, 'little', 'Gender', None)
    Strength = (0x0238, 1, False, 'little', None, 25)
    StrBonus = (0x0239, 1, False, 'little', None, 0)
    Intelligence = (0x023A, 1, False, 'little', None, 25)
    Wisdom = (0x023B, 1, False, 'little', None, 25)
    Dexterity = (0x023C, 1, False, 'little', None, 25)
    Constitution = (0x023D, 1, False, 'little', None, 25)
    Charisma = (0x023E, 1, False, 'little', None, 25)
    Morale = (0x023F, 1, False, 'little', None, 100)
    MoraleBreak = (0x0240, 1, False, 'little', None, 0)
    RacialEnemy = (0x0241, 1, False, 'little', 'Race', None)
    MoraleRecovery = (0x0242, 2, False, 'little', None, 0)
    Kit = (0x0244, 4, False, 'little', 'Kit', None)
    Race = (0x0272, 1, False, 'little', 'Race', None)
    Class = (0x0273, 1, False, 'little', 'Class', None)
    Gender = (0x0275, 1, False, 'little', 'Gender', None)
    Alignment = (0x027B, 1, False, 'little', 'Alignment', None)
    KnownSpellOffset = (0x02a0, 4, False, 'little', None, None)
    KnownSpellCount = (0x02a4, 4, False, 'little', None, None)
    MemSpellOffset = (0x02a8, 4, False, 'little', None, None)
    MemSpellCount = (0x02ac, 4, False, 'little', None, None)
    MemorizedSpellOffset = (0x02b0, 4, False, 'little', None, None)
    MemorizedSpellCount = (0x02b4, 4, False, 'little', None, None)
    ItemSlotOffset = (0x02b8, 4, False, 'little', None, None)
    ItemOffset = (0x02bc, 4, False, 'little', None, None)
    ItemCount = (0x02c0, 4, False, 'little', None, None)
    EffectOffset = (0x02c4, 4, False, 'little', None, None)
    EffectCount = (0x02c8, 4, False, 'little', None, None)
    DialogRef = (0x02cc, 8, False, 'little', None, None)

# %%
    class Magic_PALADIN(Enum):

        PALADIN_LAY_ON_HANDS = 'SPCL211'
        PALADIN_DETECT_EVIL = 'SPCL212'
        PALADIN_PROTECTION_FROM_EVIL = 'SPCL213'
        PALADIN_SUMMON_DEVA = 'SPCL923'

    class Magic_SHAMAN(Enum):

        SHAMAN_SPIRIT_FORM = 'SPCL940'
        SHAMAN_FAVORED_OF_THE_SPIRITS = 'SPCL941'

    class Magic_THIEF(Enum):

        THIEF_DETECT_ILLUSION = 'SPIN805'
        THIEF_SET_SNARE = 'SPCL412'
        THIEF_SET_SPECIAL_SNARE = 'SPCL414'

    class Magic_TOTEMIC(Enum):

        TOTEMIC_DRUID_SUMMON_SPIRIT_ANIMAL = 'SPCL621'

    class Magic_SHAPESHIFTER(Enum):

        SHAPESHIFTER_SHAPESHIFT_NATURAL_FORM = 'SPIN124'
        SHAPESHIFTER_SHAPESHIFT_WEREWOLF = 'SPCL643'
        SHAPESHIFTER_SHAPESHIFT_GREATERWEREWOLF = 'SPCL644'

    class Magic_BLACKGUARD(Enum):

        BLACKGUARD_ABSORB_HEALTH = 'SPCL102'
        BLACKGUARD_ANIMATE_DEAD = 'SPCL106'
        AURA_OF_DESPAIR = 'SPCL103'

    class Magic_RANGER(Enum):

        RANGER_CHARM_ANIMAL = 'SPCL311'
        RANGER_TRACKING = 'SPCL922'

    class Magic_BERSERKER(Enum):

        BERSERKER_ENRAGE = 'SPCL321'
        BERSERKER_RAGE = 'SPCL321'

    class Magic_ARCHER(Enum):

        ARCHER_PROTECTION = 'SPIN898'
        ARCHER_CALL_SHOT = 'SPCL121'

    class Magic_WIZARD(Enum):

        WIZARD_CHAOS_VISUALS_ONLY = 'SPWI050'
        WIZARD_DISPEL_MAGIC_VISUALS_ONLY = 'SPWI051'
        WIZARD_POWER_WORD_SILENCE_VISUALS_ONLY = 'SPWI052'
        WIZARD_FLESH_TO_STONE_IGNORE_RESISTANCE = 'SPWI053'
        WIZARD_FINGER_OF_DEATH_IGNORE_RESISTANCE = 'SPWI054'
        WIZARD_DISINTEGRATE_IGNORE_RESISTANCE = 'SPWI055'
        WIZARD_DISINTEGRATE2_IGNORE_RESISTANCE = 'SPWI056'
        WIZARD_GREASE = 'SPWI101'
        WIZARD_ARMOR = 'SPWI102'
        WIZARD_BURNING_HANDS = 'SPWI103'
        WIZARD_CHARM_PERSON = 'SPWI104'
        WIZARD_COLOR_SPRAY = 'SPWI105'
        WIZARD_BLINDNESS = 'SPWI106'
        WIZARD_FRIENDS = 'SPWI107'
        WIZARD_PROTECTION_FROM_PETRIFICATION = 'SPWI108'
        WIZARD_HOLD_PORTAL = 'SPWI109'
        WIZARD_IDENTIFY = 'SPWI110'
        WIZARD_INFRAVISION = 'SPWI111'
        WIZARD_MAGIC_MISSILE = 'SPWI112'
        WIZARD_PROTECTION_FROM_EVIL = 'SPWI113'
        WIZARD_SHIELD = 'SPWI114'
        WIZARD_SHOCKING_GRASP = 'SPWI115'
        WIZARD_SLEEP = 'SPWI116'
        WIZARD_CHILL_TOUCH = 'SPWI117'
        WIZARD_CHROMATIC_ORB = 'SPWI118'
        WIZARD_LARLOCH_MINOR_DRAIN = 'SPWI119'
        WIZARD_REFLECTED_IMAGE = 'SPWI120'
        WIZARD_REVEAL_MAGIC = 'SPWI121'
        WIZARD_PROTECTION_CIRCLE = 'SPWI122'
        WIZARD_FIND_FAMILAR = 'SPWI123'
        WIZARD_ALARM = 'SPWI124'
        WIZARD_NAHALS_RECKLESS_DWEOMER = 'SPWI124'
        WIZARD_SPOOK = 'SPWI125'
        WIZARD_BLUR = 'SPWI201'
        WIZARD_DETECT_EVIL = 'SPWI202'
        WIZARD_DETECT_INVISIBILITY = 'SPWI203'
        WIZARD_FOG_CLOUD = 'SPWI204'
        WIZARD_HORROR = 'SPWI205'
        WIZARD_INVISIBILITY = 'SPWI206'
        WIZARD_KNOCK = 'SPWI207'
        WIZARD_KNOW_ALIGNMENT = 'SPWI208'
        WIZARD_LUCK = 'SPWI209'
        WIZARD_RESIST_FEAR = 'SPWI210'
        WIZARD_MELF_ACID_ARROW = 'SPWI211'
        WIZARD_MIRROR_IMAGE = 'SPWI212'
        WIZARD_STINKING_CLOUD = 'SPWI213'
        WIZARD_STRENGTH = 'SPWI214'
        WIZARD_WEB = 'SPWI215'
        WIZARD_WIZARD_LOCK = 'SPWI216'
        WIZARD_AGANNAZAR_SCORCHER = 'SPWI217'
        WIZARD_GHOUL_TOUCH = 'SPWI218'
        WIZARD_VOCALIZE = 'SPWI219'
        WIZARD_POWER_WORD_SLEEP = 'SPWI220'
        WIZARD_RAY_OF_ENFEEBLEMENT = 'SPWI221'
        WIZARD_CHAOS_SHIELD = 'SPWI222'
        WIZARD_DEAFNESS = 'SPWI223'
        WIZARD_GLITTERDUST = 'SPWI224'
        WIZARD_CLAIRVOYANCE = 'SPWI301'
        WIZARD_DISPEL_MAGIC = 'SPWI302'
        WIZARD_REMOVE_MAGIC = 'SPWI302'
        WIZARD_FLAME_ARROW = 'SPWI303'
        WIZARD_FIREBALL = 'SPWI304'
        WIZARD_HASTE = 'SPWI305'
        WIZARD_HOLD_PERSON = 'SPWI306'
        WIZARD_INVISIBILITY_10_FOOT = 'SPWI307'
        WIZARD_LIGHTNING_BOLT = 'SPWI308'
        WIZARD_MONSTER_SUMMONING_1 = 'SPWI309'
        WIZARD_NON_DETECTION = 'SPWI310'
        WIZARD_PROTECTION_FROM_NORMAL_MISSILES = 'SPWI311'
        WIZARD_SLOW = 'SPWI312'
        WIZARD_SKULL_TRAP = 'SPWI313'
        WIZARD_VAMPIRIC_TOUCH = 'SPWI314'
        WIZARD_WRAITH_FORM = 'SPWI315'
        WIZARD_DIRE_CHARM = 'SPWI316'
        WIZARD_GHOST_ARMOR = 'SPWI317'
        WIZARD_MINOR_SPELL_DEFLECTION = 'SPWI318'
        WIZARD_PROTECTION_FROM_FIRE = 'SPWI319'
        WIZARD_PROTECTION_FROM_COLD = 'SPWI320'
        WIZARD_SPELL_THRUST = 'SPWI321'
        WIZARD_DETECT_ILLUSION = 'SPWI322'
        WIZARD_HOLD_UNDEAD = 'SPWI324'
        WIZARD_MELF_METEOR = 'SPWI325'
        WIZARD_TRUE_DISPEL_MAGIC = 'SPWI326'
        WIZARD_CONFUSION = 'SPWI401'
        WIZARD_DIMENSION_DOOR = 'SPWI402'
        WIZARD_FIRE_SHIELD_BLUE = 'SPWI403'
        WIZARD_ICE_STORM = 'SPWI404'
        WIZARD_IMPROVED_INVISIBILITY = 'SPWI405'
        WIZARD_MINOR_GLOBE_OF_INVULNERABILITY = 'SPWI406'
        WIZARD_MONSTER_SUMMONING_2 = 'SPWI407'
        WIZARD_STONE_SKIN = 'SPWI408'
        WIZARD_CONTAGION = 'SPWI409'
        WIZARD_REMOVE_CURSE = 'SPWI410'
        WIZARD_EMOTION_HOPELESSNESS = 'SPWI411'
        WIZARD_GREATER_MALISON = 'SPWI412'
        WIZARD_OTILUKES_RESILIENT_SPHERE = 'SPWI413'
        WIZARD_SPIRIT_ARMOR = 'SPWI414'
        WIZARD_POLYMORPH_OTHER = 'SPWI415'
        WIZARD_POLYMORPH_SELF = 'SPWI416'
        WIZARD_ENCHANTED_WEAPON = 'SPWI417'
        WIZARD_FIRE_SHIELD_RED = 'SPWI418'
        WIZARD_SECRET_WORD = 'SPWI419'
        WIZARD_MINOR_SEQUENCER = 'SPWI420'
        WIZARD_TELEPORT_FIELD = 'SPWI421'
        WIZARD_SPIDER_SPAWN = 'SPWI423'
        WIZARD_FAR_SIGHT = 'SPWI424'
        WIZARD_EYE = 'SPWI425'
        WIZARD_POLYMORPH_NATURAL_FORM = 'SPWI490'
        WIZARD_POLYMORPH_FLIND = 'SPWI493'
        WIZARD_POLYMORPH_OGRE = 'SPWI494'
        WIZARD_POLYMORPH_SPIDER = 'SPWI495'
        WIZARD_POLYMORPH_MUSTARD_JELLY = 'SPWI496'
        WIZARD_POLYMORPH_BROWN_BEAR = 'SPWI497'
        WIZARD_POLYMORPH_BLACK_BEAR = 'SPWI498'
        WIZARD_POLYMORPH_WOLF = 'SPWI499'
        WIZARD_ANIMATE_DEAD = 'SPWI501'
        WIZARD_CLOUDKILL = 'SPWI502'
        WIZARD_CONE_OF_COLD = 'SPWI503'
        WIZARD_MONSTER_SUMMONING_3 = 'SPWI504'
        WIZARD_SHADOW_DOOR = 'SPWI505'
        WIZARD_DOMINATION = 'SPWI506'
        WIZARD_HOLD_MONSTER = 'SPWI507'
        WIZARD_CHAOS = 'SPWI508'
        WIZARD_FEEBLEMIND = 'SPWI509'
        WIZARD_SPELL_IMMUNITY = 'SPWI510'
        WIZARD_PROTECTION_FROM_NORMAL_WEAPONS = 'SPWI511'
        WIZARD_PROTECTION_FROM_ELECTRICITY = 'SPWI512'
        WIZARD_BREACH = 'SPWI513'
        WIZARD_LOWER_RESISTANCE = 'SPWI514'
        WIZARD_ORACLE = 'SPWI515'
        WIZARD_CONJURE_LESSER_FIRE_ELEMENTAL = 'SPWI516'
        WIZARD_PROTECTION_FROM_ACID = 'SPWI517'
        WIZARD_PHANTOM_BLADE = 'SPWI518'
        WIZARD_SPELL_SHIELD = 'SPWI519'
        WIZARD_CONJURE_LESSER_AIR_ELEMENTAL = 'SPWI520'
        WIZARD_CONJURE_LESSER_EARTH_ELEMENTAL = 'SPWI521'
        WIZARD_MINOR_SPELL_TURNING = 'SPWI522'
        WIZARD_SUN_FIRE = 'SPWI523'
        WIZARD_SPELL_IMMUNITY_ABJURATION = 'SPWI590'
        WIZARD_SPELL_IMMUNITY_CONJURATION = 'SPWI591'
        WIZARD_SPELL_IMMUNITY_DIVINATION = 'SPWI592'
        WIZARD_SPELL_IMMUNITY_ENCHANTMENT = 'SPWI593'
        WIZARD_SPELL_IMMUNITY_ILLUSIONIST = 'SPWI594'
        WIZARD_SPELL_IMMUNITY_INVOCATION = 'SPWI595'
        WIZARD_SPELL_IMMUNITY_NECROMANCY = 'SPWI596'
        WIZARD_SPELL_IMMUNITY_ALTERATION = 'SPWI597'
        WIZARD_INVISIBLE_STALKER = 'SPWI601'
        WIZARD_GLOBE_OF_INVULNERABILITY = 'SPWI602'
        WIZARD_TENSERS_TRANSFORMATION = 'SPWI603'
        WIZARD_FLESH_TO_STONE = 'SPWI604'
        WIZARD_DEATH_SPELL = 'SPWI605'
        WIZARD_PROTECTION_FROM_MAGIC_ENERGY = 'SPWI606'
        WIZARD_MISLEAD = 'SPWI607'
        WIZARD_PIERCE_MAGIC = 'SPWI608'
        WIZARD_TRUE_SIGHT = 'SPWI609'
        WIZARD_MONSTER_SUMMONING_4 = 'SPWI610'
        WIZARD_PROTECTION_FROM_MAGIC_WEAPONS = 'SPWI611'
        WIZARD_POWER_WORD_SILENCE = 'SPWI612'
        WIZARD_IMPROVED_HASTE = 'SPWI613'
        WIZARD_DEATH_FOG = 'SPWI614'
        WIZARD_CHAIN_LIGHTNING = 'SPWI615'
        WIZARD_DISINTEGRATE = 'SPWI616'
        WIZARD_CONTINGENCY = 'SPWI617'
        WIZARD_SPELL_DEFLECTION = 'SPWI618'
        WIZARD_WYVERN_CALL = 'SPWI619'
        WIZARD_CONJURE_FIRE_ELEMENTAL = 'SPWI620'
        WIZARD_CONJURE_AIR_ELEMENTAL = 'SPWI621'
        WIZARD_CONJURE_EARTH_ELEMENTAL = 'SPWI622'
        WIZARD_CARRION = 'SPWI623'
        WIZARD_SUMMON_NISHRUU = 'SPWI624'
        WIZARD_STONE_TO_FLESH = 'SPWI625'
        WIZARD_SPELL_TURNING = 'SPWI701'
        WIZARD_PROTECTION_FROM_THE_ELEMENTS = 'SPWI702'
        WIZARD_PROJECT_IMAGE = 'SPWI703'
        WIZARD_RUBY_RAY_OF_REVERSAL = 'SPWI704'
        WIZARD_KHELBENS_WARDING_WHIP = 'SPWI705'
        WIZARD_WARDING_WHIP = 'SPWI705'
        WIZARD_CACOFIEND = 'SPWI707'
        WIZARD_MANTLE = 'SPWI708'
        WIZARD_TATTOOS_OF_POWER = 'SPWI709'
        WIZARD_SPELL_SEQUENCER = 'SPWI710'
        WIZARD_SPHERE_OF_CHAOS = 'SPWI711'
        WIZARD_DELAYED_BLAST_FIREBALL = 'SPWI712'
        WIZARD_FINGER_OF_DEATH = 'SPWI713'
        WIZARD_PRISMATIC_SPRAY = 'SPWI714'
        WIZARD_POWER_WORD_STUN = 'SPWI715'
        WIZARD_MORDENKAINENS_SWORD = 'SPWI716'
        WIZARD_SUMMON_EFREET = 'SPWI717'
        WIZARD_SUMMON_DJINNI = 'SPWI718'
        WIZARD_SUMMON_HAKEASHAR = 'SPWI719'
        WIZARD_CONTROL_UNDEAD = 'SPWI720'
        WIZARD_MASS_INVISIBILITY = 'SPWI721'
        WIZARD_LIMITED_WISH = 'SPWI722'
        WIZARD_IMPROVED_CHAOS_SHIELD = 'SPWI723'
        WIZARD_DELETED = 'SPWI801'
        WIZARD_PROTECTION_FROM_ENERGY = 'SPWI803'
        WIZARD_SIMULACRUM = 'SPWI804'
        WIZARD_PIERCE_SHIELD = 'SPWI805'
        WIZARD_SUMMON_FIEND = 'SPWI807'
        WIZARD_IMPROVED_MANTLE = 'SPWI808'
        WIZARD_SPELL_TRIGGER = 'SPWI809'
        WIZARD_INCENDIARY_CLOUD = 'SPWI810'
        WIZARD_SYMBOL_FEAR = 'SPWI811'
        WIZARD_ABI_DALZIMS_HORRID_WILTING = 'SPWI812'
        WIZARD_MAZE = 'SPWI813'
        WIZARD_OTTOS_IRRESISTIBLE_DANCE = 'SPWI814'
        WIZARD_POWER_WORD_BLIND = 'SPWI815'
        WIZARD_SYMBOL_STUN = 'SPWI816'
        WIZARD_SYMBOL_DEATH = 'SPWI817'
        WIZARD_BIGBYS_CLENCHED_FIST = 'SPWI818'
        WIZARD_NPC_SYMBOL_DEATH = 'SPWI897'
        WIZARD_NPC_SYMBOL_STUN = 'SPWI898'
        WIZARD_NPC_SYMBOL_FEAR = 'SPWI899'
        WIZARD_SPELL_TRAP = 'SPWI902'
        WIZARD_SPELL_STRIKE = 'SPWI903'
        WIZARD_GATE = 'SPWI905'
        WIZARD_ABSOLUTE_IMMUNITY = 'SPWI907'
        WIZARD_CHAIN_CONTINGENCY = 'SPWI908'
        WIZARD_TIME_STOP = 'SPWI909'
        WIZARD_IMPRISONMENT = 'SPWI910'
        WIZARD_METEOR_SWARM = 'SPWI911'
        WIZARD_POWER_WORD_KILL = 'SPWI912'
        WIZARD_WAIL_OF_THE_BANSHEE = 'SPWI913'
        WIZARD_ENERGY_DRAIN = 'SPWI914'
        WIZARD_BLACK_BLADE_OF_DISASTER = 'SPWI915'
        WIZARD_SHAPECHANGE = 'SPWI916'
        WIZARD_FREEDOM = 'SPWI917'
        WIZARD_BIGBYS_CRUSHING_HAND = 'SPWI918'
        WIZARD_WISH = 'SPWI919'
        WIZARD_ENERGY_BLADES = 'SPWI920'
        WIZARD_IMPROVED_ALACRITY = 'SPWI921'
        WIZARD_IMPROVED_ALUCRITY = 'SPWI921'
        WIZARD_DRAGONS_BREATH = 'SPWI922'
        WIZARD_SUMMON_PLANATAR_GOOD = 'SPWI923'
        WIZARD_SUMMON_PLANATAR_EVIL = 'SPWI924'
        WIZARD_COMET = 'SPWI925'

    class Magic_BARBARIAN(Enum):

        BARBARIAN_RAGE = 'SPCL152'

    class Magic_ASSASSIN(Enum):

        ASSASSIN_POISON = 'SPCL423'

    class Magic_BLADE(Enum):

        BLADE_OFFENSIVE_SPIN = 'SPCL521'
        BLADE_DEFENSIVE_SPIN = 'SPCL522'

    class Magic_HELL(Enum):

        HELL_BUFFET = 'SPIN658'
        HELL_SELFISH_EVIL = 'SPIN747'
        HELL_SELFISH_GOOD = 'SPIN748'
        HELL_WRATH_EVIL = 'SPIN749'
        HELL_WRATH_GOOD = 'SPIN750'
        HELL_PRIDE_EVIL = 'SPIN751'
        HELL_PRIDE_GOOD = 'SPIN752'
        HELL_FEAR_EVIL = 'SPIN753'
        HELL_FEAR_GOOD = 'SPIN754'
        HELL_GREED_EVIL = 'SPIN755'
        HELL_GREED_GOOD = 'SPIN756'
        HELL_GAIN_CHR = 'SPIN759'
        HELL_GAIN_CON = 'SPIN760'
        HELL_GAIN_DEX = 'SPIN761'
        HELL_GAIN_WIS = 'SPIN762'
        HELL_GAIN_INT = 'SPIN763'
        HELL_GAIN_STR = 'SPIN764'
        HELL_LOSE_XP = 'SPIN765'
        HELL_LOSE_DEX = 'SPIN766'
        HELL_LOSE_HP = 'SPIN767'
        HELL_DISPELL = 'SPIN768'
        HELL_HOLD = 'SPIN769'
        HELL_EXPLODE = 'SPIN770'
        HELL_DAMAGE_HALF = 'SPIN771'
        HELL_FEAR = 'SPIN772'
        HELL_HOUND_FLAME = 'SPIN956'

    class Magic_CAVALIER(Enum):

        CAVALIER_REMOVE_FEAR = 'SPCL222'

    class Magic_WILD(Enum):

        WILD_MAGIC_AREA = 'SPIN645'
        WILD_MAGIC_ZONE = 'SPIN778'

    class Magic_LATHANDER(Enum):

        LATHANDER_BOON = 'SPCL741'
        LATHANDER_HOLD_UNDEAD = 'SPCL742'

    class Magic_WARRIOR(Enum):

        WARRIOR_WHIRLWIND = 'SPCL900'
        WARRIOR_GREATER_WHIRLWIND = 'SPCL901'
        WARRIOR_DEATHBLOW = 'SPCL902'
        WARRIOR_GREATER_DEATHBLOW = 'SPCL903'
        WARRIOR_RESIST_MAGIC = 'SPCL904'
        WARRIOR_CRITICAL_STRIKE = 'SPCL905'
        WARRIOR_POWER_ATTACK = 'SPCL906'
        WARRIOR_HARDINESS = 'SPCL907'
        WARRIOR_WAR_CRY = 'SPCL908'
        WARRIOR_SMITE = 'SPCL909'

    class Magic_GAIN(Enum):

        GAIN_ONE_CHA_PERMANENT = 'SPIN554'
        GAIN_ONE_WIS_PERMANENT = 'SPIN555'
        GAIN_ONE_INT_PERMANENT = 'SPIN556'
        GAIN_ONE_DEX_PERMANENT = 'SPIN557'
        GAIN_ONE_THACO = 'SPIN577'
        GAIN_ONE_AC = 'SPIN578'
        GAIN_HASTE_TEMPORARY = 'SPIN584'
        GAIN_MAGIC_RESIST_PERMANENT = 'SPIN585'
        GAIN_ONE_CON_PERMANENT = 'SPIN590'
        GAIN_ONE_STR_PERMANENT = 'SPIN591'

    class Magic_DRUID(Enum):

        DRUID_HUMAN_FORM = 'SPIN123'
        DRUID_SHAPESHIFT_FROM_BLACKBEAR = 'SPIN123'
        DRUID_SHAPESHIFT_BROWNBEAR = 'SPCL611'
        DRUID_SHAPESHIFT_WOLF = 'SPCL612'
        DRUID_SHAPESHIFT_BLACKBEAR = 'SPCL613'
        DRUID_IMMUNE_POISON = 'SPCL924'
        DRUID_RESISTS = 'SPCL925'

    class Magic_EVIL(Enum):

        EVIL_LAYONHANDS = 'SPIN773'

    class Magic_SHADOWDANCER(Enum):

        SHADOWDANCER_SHADOW_TWIN = 'SPCL936'
        SHADOWDANCER_SHADOW_MAZE = 'SPCL937'
        SHADOWDANCER_SHADOW_FORM = 'SPCL938'

    class Magic_INNATE(Enum):

        INNATE_CURE_LIGHT_WOUNDS = 'SPIN101'
        INNATE_SLOW_POISON = 'SPIN102'
        INNATE_DRAW_UPON_HOLY_MIGHT = 'SPIN103'
        INNATE_LARLOCHS_MINOR_DRAIN = 'SPIN104'
        INNATE_HORROR = 'SPIN105'
        INNATE_VAMPIRIC_TOUCH = 'SPIN106'

    class Magic_DM(Enum):

        DM_SHIELD = 'SPIN650'
        DM_SEE_INVISIBLE = 'SPIN651'
        DM_MAGIC_PROTECTION = 'SPIN652'
        DM_COLD_PROTECTION = 'SPIN653'
        DM_FIRE_PROTECTION = 'SPIN654'
        DM_IMPROVED_HASTE = 'SPIN655'

    class Magic_MONK(Enum):

        MONK_STUNNING_BLOW = 'SPCL811'
        MONK_LAY_ON_HANDS = 'SPCL815'
        MONK_QUIVERING_PALM = 'SPCL820'

    class Magic_AVENGER(Enum):

        AVENGER_SHAPESHIFT_NATURAL_FORM = 'SPIN122'
        AVENGER_SHAPESHIFT_SWORDSPIDER = 'SPCL632'
        AVENGER_SHAPESHIFT_BABYWYVERN = 'SPCL633'
        AVENGER_SHAPESHIFT_FIRESALAMANDER = 'SPCL634'

    class Magic_ROGUE(Enum):

        ROGUE_SET_SPIKE_TRAP = 'SPCL910'
        ROGUE_SET_EXPLODING_TRAP = 'SPCL911'
        ROGUE_SET_TIME_TRAP = 'SPCL912'
        ROGUE_EVASION = 'SPCL913'
        ROGUE_GREATER_EVASION = 'SPCL914'
        ROGUE_ASSASINATION = 'SPCL916'
        ROGUE_AVOID_DEATH = 'SPCL917'

    class Magic_BOOK(Enum):

        BOOK_GOLEM = 'SPIN840'
        BOOK_BEHOLD = 'SPIN841'
        BOOK_MIND = 'SPIN842'
        BOOK_UMBER = 'SPIN843'
        BOOK_SPIDER = 'SPIN844'
        BOOK_KOBOLD = 'SPIN845'

    class Magic_INQUIS(Enum):

        INQUIS_DISPEL_MAGIC = 'SPCL231'
        INQUIS_TRUE_SIGHT = 'SPCL232'

    class Magic_BEASTMASTER(Enum):

        BEASTMASTER_FIND_FAMILIAR = 'SPCL342'

    class Magic_POWERWORD(Enum):

        POWERWORD_BLIND = 'SPWI958'
        POWERWORD_STUN = 'SPWI959'
        POWERWORD_KILL = 'SPWI960'

    class Magic_CLERIC(Enum):

        CLERIC_BLESS = 'SPPR101'
        CLERIC_COMMAND = 'SPPR102'
        CLERIC_CURE_LIGHT_WOUNDS = 'SPPR103'
        CLERIC_DETECT_EVIL = 'SPPR104'
        CLERIC_ENTANGLE = 'SPPR105'
        CLERIC_MAGIC_STONE = 'SPPR106'
        CLERIC_PROTECT_FROM_EVIL = 'SPPR107'
        CLERIC_REMOVE_FEAR = 'SPPR108'
        CLERIC_SANCTUARY = 'SPPR109'
        CLERIC_SHILLELAGH = 'SPPR110'
        CLERIC_ARMOR_OF_FAITH = 'SPPR111'
        CLERIC_CIRCLE_OF_PROTECTION = 'SPPR112'
        CLERIC_DOOM = 'SPPR113'
        CLERIC_ANIMAL_FRIENDSHIP = 'SPPR114'
        CLERIC_ENDURE_HEAT_COLD = 'SPPR115'
        CLERIC_SPIRIT_WARD = 'SPPR150'
        CLERIC_AID = 'SPPR201'
        CLERIC_BARKSKIN = 'SPPR202'
        CLERIC_CHANT = 'SPPR203'
        CLERIC_CHARM_PERSON = 'SPPR204'
        CLERIC_FIND_TRAPS = 'SPPR205'
        CLERIC_FLAME_BLADE = 'SPPR206'
        CLERIC_GOOD_BERRIES = 'SPPR207'
        CLERIC_HOLD_PERSON = 'SPPR208'
        CLERIC_KNOW_ALIGNMENT = 'SPPR209'
        CLERIC_RESIST_FIRE = 'SPPR210'
        CLERIC_SILENCE_15_FOOT = 'SPPR211'
        CLERIC_SLOW_POISON = 'SPPR212'
        CLERIC_SPIRITUAL_HAMMER = 'SPPR213'
        CLERIC_DRAW_UPON_HOLY_MIGHT = 'SPPR214'
        CLERIC_RESIST_COLD = 'SPPR215'
        CLERIC_WRITHING_FOG = 'SPPR250'
        CLERIC_ANIMATE_DEAD = 'SPPR301'
        CLERIC_CALL_LIGHTNING = 'SPPR302'
        CLERIC_DISPEL_MAGIC = 'SPPR303'
        CLERIC_GLYPH_OF_WARDING = 'SPPR304'
        CLERIC_HOLD_ANIMAL = 'SPPR305'
        CLERIC_PROTECTION_FROM_FIRE = 'SPPR306'
        CLERIC_REMOVE_CURSE = 'SPPR307'
        CLERIC_REMOVE_PARALYSIS = 'SPPR308'
        CLERIC_INVISIBILITY_PURGE = 'SPPR309'
        CLERIC_MISCAST_MAGIC = 'SPPR310'
        CLERIC_RIGID_THINKING = 'SPPR311'
        CLERIC_STRENGTH_OF_ONE = 'SPPR312'
        CLERIC_HOLY_SMITE = 'SPPR313'
        CLERIC_UNHOLY_BLIGHT = 'SPPR314'
        CLERIC_CURE_MEDIUM_WOUNDS = 'SPPR315'
        CLERIC_CURE_BLIND_DEAF = 'SPPR316'
        CLERIC_CURE_DISEASE = 'SPPR317'
        CLERIC_ZONE_OF_SWEET_AIR = 'SPPR318'
        CLERIC_SUMMON_INSECTS = 'SPPR319'
        CLERIC_SPIRITUAL_CLARITY = 'SPPR350'
        CLERIC_CURE_SERIOUS_WOUNDS = 'SPPR401'
        CLERIC_ANIMAL_SUMMONING_1 = 'SPPR402'
        CLERIC_FREE_ACTION = 'SPPR403'
        CLERIC_NEUTRALIZE_POISON = 'SPPR404'
        CLERIC_MENTAL_DOMINATION = 'SPPR405'
        CLERIC_DEFENSIVE_HARMONY = 'SPPR406'
        CLERIC_PROTECTION_FROM_LIGHTNING = 'SPPR407'
        CLERIC_PROTECTION_FROM_EVIL_10_FOOT = 'SPPR408'
        CLERIC_DEATH_WARD = 'SPPR409'
        CLERIC_CALL_WOODLAND_BEINGS = 'SPPR410'
        CLERIC_POISON = 'SPPR411'
        CLERIC_HOLY_POWER = 'SPPR412'
        CLERIC_NEGATIVE_PLANE_PROTECTION = 'SPPR413'
        CLERIC_CAUSE_SERIOUS_WOUNDS = 'SPPR414'
        CLERIC_FAR_SIGHT = 'SPPR415'
        CLERIC_CLOAK_OF_FEAR = 'SPPR416'
        CLERIC_LESSER_RESTORATION = 'SPPR417'
        CLERIC_SPIRIT_FIRE = 'SPPR450'
        CLERIC_ANIMAL_SUMMONING_2 = 'SPPR501'
        CLERIC_CURE_CRITICAL_WOUNDS = 'SPPR502'
        CLERIC_FLAME_STRIKE = 'SPPR503'
        CLERIC_RAISE_DEAD = 'SPPR504'
        CLERIC_TRUE_SIGHT = 'SPPR505'
        CLERIC_IRONSKIN = 'SPPR506'
        CLERIC_CHAMPIONS_STRENGTH = 'SPPR507'
        CLERIC_CHAOTIC_COMMANDS = 'SPPR508'
        CLERIC_MAGIC_RESISTANCE = 'SPPR509'
        CLERIC_CAUSE_CRITICAL_WOUNDS = 'SPPR510'
        CLERIC_SLAY_LIVING = 'SPPR511'
        CLERIC_GREATER_COMMAND = 'SPPR512'
        CLERIC_RIGHTEOUS_MAGIC = 'SPPR513'
        CLERIC_MASS_CURE = 'SPPR514'
        CLERIC_REPULSE_UNDEAD = 'SPPR515'
        CLERIC_PIXIE_DUST = 'SPPR516'
        CLERIC_INSECT_PLAGUE = 'SPPR517'
        CLERIC_RECALL_SPIRIT = 'SPPR550'
        CLERIC_AERIAL_SERVANT = 'SPPR601'
        CLERIC_ANIMAL_SUMMONING_3 = 'SPPR602'
        CLERIC_BLADE_BARRIER = 'SPPR603'
        CLERIC_CONJURE_ANIMALS = 'SPPR604'
        CLERIC_CONJURE_FIRE_ELEMENTAL = 'SPPR605'
        CLERIC_FIRE_SEEDS = 'SPPR606'
        CLERIC_HEAL = 'SPPR607'
        CLERIC_HARM = 'SPPR608'
        CLERIC_FALSE_DAWN = 'SPPR609'
        CLERIC_DOLOROUS_DECAY = 'SPPR610'
        CLERIC_WONDROUS_RECALL = 'SPPR611'
        CLERIC_BOLT_OF_GLORY = 'SPPR612'
        CLERIC_PHYSICAL_MIRROR = 'SPPR613'
        CLERIC_SOL_SEARING_ORB = 'SPPR614'
        CLERIC_SPIRITUAL_LOCK = 'SPPR650'
        CLERIC_SHIELD_OF_THE_ARCHONS = 'SPPR701'
        CLERIC_CONJURE_EARTH_ELEMENTAL = 'SPPR702'
        CLERIC_GATE = 'SPPR703'
        CLERIC_NATURE_BEAUTY = 'SPPR704'
        CLERIC_FIRE_STORM = 'SPPR705'
        CLERIC_SYMBOL_FEAR = 'SPPR706'
        CLERIC_SUNRAY = 'SPPR707'
        CLERIC_FINGER_OF_DEATH = 'SPPR708'
        CLERIC_CONFUSION = 'SPPR709'
        CLERIC_HOLY_WORD = 'SPPR710'
        CLERIC_REGENERATE = 'SPPR711'
        CLERIC_RESURRECTION = 'SPPR712'
        CLERIC_RESTORATION = 'SPPR713'
        CLERIC_ENERGY_DRAIN = 'SPPR714'
        CLERIC_UNHOLY_WORD = 'SPPR715'
        CLERIC_SPACE_WARP = 'SPPR716'
        CLERIC_CREEPING_DOOM = 'SPPR717'
        CLERIC_SYMBOL_STUN = 'SPPR718'
        CLERIC_SYMBOL_DEATH = 'SPPR719'
        CLERIC_EARTHQUAKE = 'SPPR720'
        CLERIC_ENERGY_BLADES = 'SPPR721'
        CLERIC_STORM_OF_VENGEANCE = 'SPPR722'
        CLERIC_ELEMENTAL_SWARM = 'SPPR723'
        CLERIC_GREATER_ELEMENTAL_SWARM = 'SPPR724'
        CLERIC_GLOBE_OF_BLADES = 'SPPR725'
        CLERIC_SUMMON_DEVA = 'SPPR726'
        CLERIC_SUMMON_FALLEN_DEVA = 'SPPR727'
        CLERIC_IMPLOSION = 'SPPR728'
        CLERIC_MASS_RAISE_DEAD = 'SPPR729'
        CLERIC_AURA_OF_FLAMING_DEATH = 'SPPR730'
        CLERIC_ELEMENTAL_TRANSFORMATION_FIRE = 'SPPR731'
        CLERIC_ELEMENTAL_TRANSFORMATION_EARTH = 'SPPR732'
        CLERIC_ETHER_GATE = 'SPPR750'
        CLERIC_ETHEREAL_RETRIBUTION = 'SPPR751'

    class Magic_KENSAI(Enum):

        KENSAI_KIA = 'SPCL144'

    class Magic_WISH(Enum):

        WISH_SPELL_FAILURE = 'SPIN731'
        WISH_LOSE_SPELL = 'SPIN732'
        WISH_POISON = 'SPIN733'
        WISH_HEAL_PARTY = 'SPIN734'
        WISH_RABBIT = 'SPIN735'
        WISH_GLOBE = 'SPIN736'
        WISH_MEMORIZE = 'SPIN737'
        WISH_PLANE = 'SPIN738'

    class Magic_TRAP(Enum):

        TRAP_DIRE_CHARM = 'SPPR982'
        TRAP_CONFUSION = 'SPPR983'
        TRAP_CHROMATIC_ORB = 'SPPR984'
        TRAP_FLAMESTRIKE = 'SPPR985'
        TRAP_MISCAST_MAGIC = 'SPPR986'
        TRAP_CALL_LIGHTNING = 'SPPR987'
        TRAP_SILENCE = 'SPPR988'
        TRAP_HOLD_PERSON = 'SPPR989'
        TRAP_FIREBALL = 'SPWI001'
        TRAP_LIGHTNING_BOLT = 'SPWI002'
        TRAP_MAGIC_MISSILE = 'SPWI003'
        TRAP_STINKING_CLOUD = 'SPWI004'
        TRAP_ARROW = 'SPWI005'
        TRAP_ARROW_SLAYING = 'SPWI006'
        TRAP_ARROW_ACID = 'SPWI007'
        TRAP_ARROW_BITING = 'SPWI008'
        TRAP_ARROW_DETONATION = 'SPWI009'
        TRAP_ARROW_DISPELLING = 'SPWI010'
        TRAP_ARROW_FIRE = 'SPWI011'
        TRAP_ARROW_ICE = 'SPWI012'
        TRAP_ARROW_PIERCING = 'SPWI013'
        TRAP_MONSTER_SUMMONING = 'SPWI014'
        TRAP_FROST = 'SPWI015'
        TRAP_CLOUDKILL = 'SPWI016'
        TRAP_MINOR_LIGHTNING_BOLT = 'SPWI017'
        TRAP_UNDERWATER_BITE = 'SPWI020'
        TRAP_HALLWAY_SPIKES = 'SPWI021'
        TRAP_MUCK = 'SPWI022'
        TRAP_SHADOW_DEATH = 'SPWI023'
        TRAP_GUILLOTINE = 'SPWI024'
        TRAP_LIGHTNING_ORB1 = 'SPWI025'
        TRAP_LIGHTNING_ORB2 = 'SPWI026'
        TRAP_LIGHTNING_ORB3 = 'SPWI027'
        TRAP_PENDULUM = 'SPIN705'
        TRAP_VENT = 'SPIN706'
        TRAP_DARTS = 'SPIN707'
        TRAP_SLIME = 'SPIN708'
        TRAP_SPEAR = 'SPIN709'

    class Magic_TALOS(Enum):

        TALOS_STORMSHIELD = 'SPCL721'
        TALOS_LIGHTNING_BOLT = 'SPCL722'

    class Magic_SUN(Enum):

        SUN_SOUL_SUN_SOULRAY = 'SPCL236'
        SUN_SOUL_GREATER_SUN = 'SPCL237'
        SUN_SOUL_SUN_SOULBEAM = 'SPCL239'

    class Magic_HELM(Enum):

        HELM_RITUAL_SCROLL = 'SPIN592'
        HELM_SEEKING_SWORD = 'SPCL731'
        HELM_TRUE_SIGHT = 'SPCL732'

# %%
class Items:

    class AMULETS(Enum):

        Necklace_of_Missiles = 'AMUL01'
        Necklace = 'AMUL02'
        Studded_Necklace_with_Zios_Gems = 'AMUL04'
        Bluestone_Necklace = 'AMUL05'
        Agni_Mani_Necklace = 'AMUL06'
        Rainbow_Obsidian_Necklace = 'AMUL07'
        Tiger_Cowrie_Shell_Necklace = 'AMUL08'
        Silver_Necklace = 'AMUL09'
        Gold_Necklace = 'AMUL10'
        Pearl_Necklace = 'AMUL11'
        Laerals_Tear_Necklace = 'AMUL12'
        Bloodstone_Amulet = 'AMUL13'
        Amulet_of_Protection_PLUS1 = 'AMUL14'
        Shield_Amulet = 'AMUL15'
        Amulet_of_Metaspell_Influence = 'AMUL16'
        Greenstone_Amulet = 'AMUL17'
        Wolfsbane_Charm_PLUS2_vs_Lycanthropes = 'AMUL18'
        Amulet_of_5 = 'AMUL19'
        Kaliguns_Amulet_of_Magic_Resistance = 'AMUL20'
        Amulet_of_Power = 'AMUL21'
        Periapt_of_Proof_Against_Poison = 'AMUL22'
        Periapt_of_Life_Protection = 'AMUL23'
        Necklace_of_Form_Stability = 'AMUL24'
        Amulet_of_Spell_Warding = 'AMUL25'
        Amulet_of_Cheetah_Speed = 'AMUL26'
        Amulet_of_Seldarine = 'AMUL27'
        Amulet_of_the_Master_Harper = 'AMUL28'

    class ARROWS(Enum):

        Arrow = 'AROW01'
        Arrow_PLUS1 = 'AROW02'
        Arrow_of_Slaying = 'AROW03'
        Acid_Arrow = 'AROW04'
        Arrow_of_Biting = 'AROW05'
        Arrow_of_Detonation = 'AROW06'
        Arrow_or_Dispelling = 'AROW07'
        Arrow_of_Fire = 'AROW08'
        Arrow_of_Ice = 'AROW09'
        Arrow_of_Piercing = 'AROW10'
        Arrow_PLUS2 = 'AROW11'
        Arrow_of_Biting_1 = 'AROW12'
        Arrow_PLUS2_1 = 'AROW1A'
        Arrow_PLUS3 = 'AROW15'

    class AXES(Enum):

        Battle_Axe = 'AX1H01'
        Battle_Axe_PLUS1 = 'AX1H02'
        Battle_Axe_PLUS2 = 'AX1H03'
        Throwing_Axe = 'AX1H04'
        Throwing_Axe_PLUS2 = 'AX1H05'
        Throwing_Axe_PLUS2_1 = 'AX1H06'
        Balas_Axe = 'AX1H07'
        Hangards_Axe_PLUS2 = 'AX1H08'
        Rifthome_Axe_PLUS3 = 'AX1H09'
        Azuredge_Axe_PLUS3 = 'AX1H10'
        Battle_Axe_PLUS2_1 = 'AX1H11'
        Battle_Axe_PLUS3_Stonefire = 'AX1H12'
        Battle_Axe_PLUS3_Frostreaver = 'AX1H13'
        Axe_of_the_Unyielding_PLUS3 = 'AX1H14'
        Axe_of_the_Unyielding_PLUS5 = 'AX1H15'
        Klogarath_PLUS4 = 'AX1H16'
        Battle_Axe_PLUS3 = 'AX1H17'

    class BAGS(Enum):

        Gem_Bag = 'BAG02'
        Scroll_Case = 'BAG03'
        Bag_of_Holding = 'BAG04'
        Ammo_Belt = 'BAG05'
        Potion_Case = 'BAG06'
        Bag_of_Holding_1 = 'BAG19'
        Bag_of_Holding_2 = 'BAG20 to BAG31'

    class BELTS(Enum):

        Girdle = 'BELT01'
        Golden_Girdle = 'BELT02'
        Girdle_of_Bluntness = 'BELT03'
        Girdle_of_Piercing = 'BELT04'
        Girdle_of_MasculinityFemininity = 'BELT05'
        Girdle_of_Hill_Giant_Strength = 'BELT06'
        Girdle_of_Stone_Giant_Strength = 'BELT07'
        Girdle_of_Frost_Giant_Strength = 'BELT08'
        Girdle_of_Fortitude = 'BELT09'
        Belt_of_Inertial_Barrier = 'BELT10'
        Girdle_of_Fire_Giant_Strength = 'BELT11'
        Imoens_Belt = 'MEL01'

    class BLUNT_WEAPONS(Enum):

        Club = 'BLUN01'
        Flail = 'BLUN02'
        Flail_PLUS1 = 'BLUN03'
        Mace = 'BLUN04'
        Mace_PLUS1 = 'BLUN05'
        Morning_Star = 'BLUN06'
        Morning_Star_PLUS1 = 'BLUN07'
        Flail_1 = 'BLUN08'
        Kiels_Morningstar = 'BLUN09'
        The_Root_of_the_Problem_Club_PLUS1_PLUS3_vs_unnatural_creatures = 'BLUN10'
        Mace_1 = 'BLUN11'
        Mace_of_Disruption_PLUS1 = 'BLUN12'
        Flail_PLUS2 = 'BLUN13'
        Flail_of_Ages_PLUS3 = 'BLUN14'
        Flail_Head = 'BLUN14A'
        Flail_Head_1 = 'BLUN14B'
        Flail_Head_2 = 'BLUN14C'
        Flail_of_Ages = 'BLUN14D'
        Flail_of_Ages_1 = 'BLUN14E'
        Flail_of_Ages_2 = 'BLUN14F'
        Flail_of_Ages_3 = 'BLUN14G'
        Flail_of_Ages_4 = 'BLUN14H'
        Flail_of_Ages_5 = 'BLUN14I'
        Morning_Star_PLUS2 = 'BLUN15'
        Morningstar_PLUS_2_The_Sleeper = 'BLUN16'
        Morningstar_PLUS2_Wyverns_Tail = 'BLUN17'
        Mace_PLUS3_Skullcrusher = 'BLUN18'
        Mace_PLUS2_Maulers_Arm = 'BLUN19'
        Mace_PLUS1_Ardulias_Fall = 'BLUN20'
        Mace_PLUS2 = 'BLUN21'
        Club_PLUS3_Blackblood = 'BLUN22'
        Bone_Club_PLUS2_PLUS3_vs_Undead = 'BLUN23'
        Club_PLUS2_Gnasher = 'BLUN24'
        Mace_of_Disruption_PLUS2 = 'BLUN25'
        Club_of_Detonation_PLUS3 = 'BLUN26'
        Club_of_Detonation_PLUS5 = 'BLUN27'
        Storm_Star_PLUS3 = 'BLUN28'
        Storm_Star_PLUS5 = 'BLUN29'
        Flail_of_Ages_PLUS5 = 'BLUN30'
        Flail_Head_3 = 'BLUN30A'
        Flail_Head_4 = 'BLUN30B'
        Flail_of_Ages_PLUS4 = 'BLUN30C'
        Flail_of_Ages_PLUS4_1 = 'BLUN30D'
        Club_PLUS3 = 'BLUN31'
        Flail_PLUS3 = 'BLUN32'
        Mace_PLUS3 = 'BLUN33'
        Morning_Star_PLUS3 = 'BLUN34'
        Ice_Star_PLUS4 = 'BLUN35'

    class BOLTS(Enum):

        Bolt = 'BOLT01'
        Bolt_PLUS1 = 'BOLT02'
        Bolt_of_Lightning = 'BOLT03'
        Bolt_of_Biting = 'BOLT04'
        Bolt_of_Polymorphing = 'BOLT05'
        Bolt_PLUS2 = 'BOLT06'
        Flasher_Master_Bruiser_Mate = 'BOLT07'
        Blessed_Bolt = 'BOLT08'
        Bolt_PLUS3 = 'BOLT09'

    class BOOKS(Enum):

        Magical_Book = 'BOOK01'
        Spell_Book = 'BOOK02'
        Manual_of_Bodily_Health_PLUS1_Con = 'BOOK03'
        Manual_of_Gainful_Exercise_PLUS1_Str = 'BOOK04'
        Manual_of_Quickness_of_Action_PLUS1_Dex = 'BOOK05'
        Tome_of_Clear_Thought_PLUS1_Int = 'BOOK06'
        Tome_of_Leadership_and_Influence_PLUS1_Chr = 'BOOK07'
        Tome_of_Understanding_PLUS1_Wis = 'BOOK08'
        Normal_Book = 'BOOK09'
        # miscellaneous_Histories = '|'
        Book_of_Ancient_KnowledgeHistory_of_the_Nether_Scrolls = 'BOOK68'
        Yagos_Book_of_Curses = 'BOOK70'
        # miscellaneous_Dusty_Books = '|'
        Baldurans_Log_Book = 'BOOK87'
        The_Recipes_and_Ruminations_of_One_Dradeel_of_Tethir = 'BOOK88'
        The_Book_of_Kaza = 'BOOK89'
        Golem_Building_Book = 'BOOK90'
        Tome_of_Amaunator = 'BOOK91'
        Merellas_Journal = 'BOOK92'
        Orcish_Cookbook = 'BOOK93'
        The_Vapiricus_Omnibus_Unabridged = 'BOOK94'
        Dea_Vampir_Becomos = 'BOOK95'
        Conjur_Ota_Servanta = 'BOOK96'
        Lellyns_Journal = 'BOOK97'
        Book_of_King_Strohm_III = 'BOOK98'
        Yaga_Shuras_Journal = 'HGBOOK1'

    class BOOTS(Enum):

        Boots_of_Speed = 'BOOT01'
        Boots_of_Stealth = 'BOOT02'
        Boots_of_the_North = 'BOOT03'
        Boots_of_Avoidance = 'BOOT04'
        Boots_of_Grounding = 'BOOT05'
        Worn_Out_Boots = 'BOOT06'
        Boots_of_Elvenkind = 'BOOT07'
        Boots_of_Phasing = 'BOOT08'
        Boots = 'BOOT09'
        Boots_of_Lightning_Speed = 'BOOT10'
        Boots_of_Etherealness = 'BOOT11'
        Gargoyle_Boots = 'BOOT12'
        Drizzts_Boots_of_Speed = 'BOOTDRIZ'

    class BOWS(Enum):

        Composite_Long_Bow = 'BOW01'
        Composite_Long_Bow_PLUS1 = 'BOW02'
        Long_Bow = 'BOW03'
        Long_Bow_PLUS1 = 'BOW04'
        Short_Bow = 'BOW05'
        Short_Bow_PLUS1 = 'BOW06'
        Long_Bow_of_Marksmanship = 'BOW07'
        Eagle_Bow = 'BOW08'
        Ripper_PLUS2 = 'BOW09'
        Heartseeker_PLUS3 = 'BOW10'
        Strong_Arm_PLUS2 = 'BOW11'
        Elven_Court_Bow_PLUS3 = 'BOW12'
        Mana_Bow_PLUS4 = 'BOW13'
        Tuigan_Short_Bow_PLUS1 = 'BOW14'
        Tansherons_Short_Bow_PLUS3 = 'BOW15'
        Composite_Long_Bow_PLUS2 = 'BOW16'
        Long_Bow_PLUS2 = 'BOW17'
        Short_Bow_PLUS2 = 'BOW18'
        Short_Bow_of_Gesen = 'BOW19'
        Gesen_Bow_Shaft = 'BOW19A'
        Gesen_Bow_String = 'BOW19B'
        Darkfire_Bow_PLUS4 = 'BOW20'
        Darkfire_Bow_PLUS5 = 'BOW21'
        Taralash_PLUS4 = 'BOW22'
        Taralash_PLUS5 = 'BOW23'
        Composite_Long_Bow_PLUS3 = 'BOW24'
        Long_Bow_PLUS3 = 'BOW25'
        Short_Bow_PLUS3 = 'BOW26'
        Eagle_Bow_1 = 'BOW99'
        Bow_of_Arvoreen = 'NPBOW'

    class BRACERS(Enum):

        Bracers_of_Defense_AC_8 = 'BRAC01'
        Bracers_of_Defense_AC_7 = 'BRAC02'
        Bracers_of_Defense_AC_6 = 'BRAC03'
        Bracers_of_Archery = 'BRAC04'
        Bracers = 'BRAC05'
        Gauntlets_of_Ogre_Power = 'BRAC06'
        Gauntlets_of_Dexterity = 'BRAC07'
        Gauntlets_of_Fumbling = 'BRAC08'
        Gauntlets_of_Weapon_Skill = 'BRAC09'
        Gauntlets_of_Weapon_Expertise = 'BRAC10'
        Bracers_of_Binding = 'BRAC11'
        Bracers_1 = 'BRAC12'
        Bracers_of_Defense_AC_5 = 'BRAC13'
        Bracers_of_Defense_AC_4 = 'BRAC14'
        Bracers_of_Defense_AC_3 = 'BRAC15'
        Bracers_of_Blinding_Strike = 'BRAC16'
        Gloves_of_Pick_Pocketing = 'BRAC17'
        Gloves_of_Missile_Snaring = 'BRAC18'
        Gauntlets_of_Crushing = 'BRAC19'
        Gloves_of_Healing = 'BRAC20'
        Gauntlets_of_Extraordinary_Specialization = 'BRAC21'
        Paladins_Bracers = 'BRAC22'
        Blessed_Bracers = 'BRAC23'
        Bards_Gloves = 'BRAC24'
        Wondrous_Gloves = 'BRAC25'
        TzuZans_Bracers = 'BRAC26'

    class BULLETS(Enum):

        Bullet = 'BULL01'
        Bullet_PLUS1 = 'BULL02'
        Bullet_PLUS2 = 'BULL03'
        Sunstone_Bullet_PLUS1 = 'BULL04'
        Bullet_PLUS3 = 'BULL05'
        Bullet_PLUS4 = 'BULL06'

    class CHAINMAILS(Enum):

        Chainmail = 'CHAN01'
        Chainmail_PLUS1 = 'CHAN02'
        Chainmail_PLUS2 = 'CHAN03'
        Splint_Mail = 'CHAN04'
        Splint_Mail_PLUS1 = 'CHAN05'
        Mithril_Chain_Mail_PLUS4 = 'CHAN06'
        Chain_Mail_PLUS3 = 'CHAN07'
        Chain_Mail_PLUS2 = 'CHAN08'
        Darkmail_PLUS3 = 'CHAN09'
        Jesters_Chain_PLUS4 = 'CHAN10'
        Crimson_Chain_PLUS5 = 'CHAN11'
        Elven_Chain_Mail = 'CHAN12'
        Elven_Chain_PLUS1 = 'CHAN13'
        Sylvan_Chain_PLUS2 = 'CHAN14'
        Melodic_Chain_PLUS3 = 'CHAN15'
        Bladesinger_Chain_PLUS4 = 'CHAN16'
        Ashen_Scales_PLUS2 = 'CHAN17'
        Armor_of_Faith_PLUS3 = 'CHAN18'
        Aslyferund_Elven_Chain_PLUS5 = 'CHAN19'
        White_Dragon_Scale = 'CHAN20'
        Chain_Mail_PLUS3_1 = 'CHAN21'
        Corthala_Family_Armor = 'NPCHAN'

    class ROBES(Enum):

        Cloak_of_Protection_PLUS1 = 'CLCK01'
        Cloak_of_Protection_PLUS2 = 'CLCK02'
        Cloak_of_Displacement = 'CLCK03'
        Cloak_of_the_Wolf = 'CLCK04'
        Cloak_of_Balduran = 'CLCK05'
        Cloak_of_NonDetection = 'CLCK06'
        Nymph_Cloak = 'CLCK07'
        Algernons_Cloak = 'CLCK08'
        Mage_Robe_of_Cold_Resistance = 'CLCK09'
        Mage_Robe_of_Fire_Resistance = 'CLCK10'
        Mage_Robe_of_Electrical_Resistance = 'CLCK11'
        Knaves_Robe = 'CLCK12'
        Travellers_Robe = 'CLCK13'
        Adventurers_Robe = 'CLCK14'
        Robe_of_the_Good_Archmagi = 'CLCK15'
        Robe_of_the_Neutral_Archmagi = 'CLCK16'
        Robe_of_the_Evil_Archmagi = 'CLCK17'
        Knaves_Robe_1 = 'CLCK18'
        Robe_of_the_Good_Archmagi_1 = 'CLCK19'
        Cloak_of_the_Shield = 'CLCK20'
        Holy_cloak = 'CLCK21'
        Shandalars_cloak = 'CLCK22'
        Cloak_of_Elvenkind = 'CLCK23'
        Cloak_of_Reflection = 'CLCK24'
        Cloak_of_the_Stars = 'CLCK25'
        Cloak_of_Mirroring = 'CLCK26'
        Cloak_of_the_Sewers = 'CLCK27'
        Shadow_Thief_Cloak = 'CLCK28'
        Robe_of_the_Apprenti = 'CLCK29'
        Cloak_of_Bravery = 'CLCK30'
        Improved_Cloak_of_Protection_PLUS2 = 'CLCK31'
        Montolios_Cloak = 'CLCK32'
        Jansen_AdventureWear = 'NPARM'
        Cloak_of_the_High_Forest = 'NPCLCK'
        Liquid_Mercury = 'COMPON01'
        Eye_of_Tyr = 'COMPON02'
        Fflars_Scabbard = 'COMPON03'
        Baalors_Claw = 'COMPON04'
        Roranachs_Horn = 'COMPON05'
        Skull_of_the_Lich = 'COMPON06'
        Hindos_Hand = 'COMPON07'
        Starfall_Ore = 'COMPON08'
        Rune_of_Clangeddin = 'COMPON09'
        Bowstring_of_Gond = 'COMPON10'
        Montolios_Clasp = 'COMPON11'
        Horn = 'COMPON12'
        Horn_1 = 'COMPON13'
        Nymphs_Tear = 'COMPON14'
        Heart_of_the_Damned = 'COMPON15'
        Montolios_Cloak_1 = 'COMPON16'
        Circlet_of_Netheril = 'COMPON17'
        White_Dragon_Scales = 'COMPON18'
        Blue_Dragon_Scales = 'COMPON19'
        Golem_Manual = 'TOME01'
        Clay_Golem_Manual = 'TOME02'
        Clay_Golem_Page = 'TOME02A'
        Stone_Golem_Manual = 'TOME03'
        Stone_Golem_Page = 'TOME03A'
        Juggernaut_Golem_Manual = 'TOME04'
        Juggernaut_Golem_Page = 'TOME04A'

    class CROSSBOWS(Enum):

        Heavy_Crossbow = 'XBOW01'
        Heavy_Crossbow_PLUS1 = 'XBOW02'
        Heavy_Crossbow_of_Accuracy = 'XBOW03'
        Light_Crossbow = 'XBOW04'
        Light_Crossbow_PLUS1 = 'XBOW05'
        Light_Crossbow_of_Speed = 'XBOW06'
        Heavy_Crossbow_PLUS2 = 'XBOW07'
        Giant_Hair_Crossbow_PLUS3 = 'XBOW08'
        Light_Crossbow_PLUS2 = 'XBOW09'
        Necaradans_Crossbow_PLUS3 = 'XBOW10'
        Flasher_Launcher = 'XBOW12'
        Crossbow_of_Affliction_PLUS4 = 'XBOW13'
        Heavy_Crossbow_of_Searing_PLUS1 = 'XBOW14'
        Firetooth_PLUS4 = 'XBOW15'
        Firetooth_PLUS5 = 'XBOW16'
        Heavy_Crossbow_PLUS3 = 'XBOW17'
        Light_Crossbow_PLUS3 = 'XBOW18'

    class DAGGERS(Enum):

        Dagger = 'DAGG01'
        Dagger_PLUS1 = 'DAGG02'
        Dagger_PLUS2 = 'DAGG03'
        Dagger_PLUS2_Longtooth = 'DAGG04'
        Throwing_Dagger = 'DAGG05'
        Nesters_Dagger = 'DAGG06'
        Kylees_Dagger = 'DAGG07'
        Hentolds_Dagger = 'DAGG08'
        Soultaker_Dagger = 'DAGG10'
        Boomerang_Dagger_PLUS2 = 'DAGG11'
        Dagger_of_Throwing_PLUS3_Firetooth = 'DAGG12'
        Pixie_Prick_PLUS3 = 'DAGG13'
        Dagger_PLUS4_BoneBlade = 'DAGG14'
        Dagger_PLUS2_1 = 'DAGG15'
        Poisoned_Throwing_Dagger = 'DAGG16'
        Stiletto_of_Demarchess_PLUS2 = 'DAGG17'
        Shadow_Thief_Dagger = 'DAGG18'
        Dagger_of = 'DAGG19'
        Dagger_PLUS4_LifeStealer = 'DAGG20'
        Dagger_of_the_Star_PLUS4 = 'DAGG21'
        Dagger_of_the_Star_PLUS5 = 'DAGG22'
        Ixils_Spike = 'DAGG23'
        Dagger_PLUS3 = 'DAGG24'
        Nebs_Nasty_Cutter = 'NEBDAG'
        Dagger_of_Venom = 'MISC75'

    class DARTS(Enum):

        Dart = 'DART01'
        Dart_PLUS1 = 'DART02'
        Dart_of_Stunning = 'DART03'
        Dart_of_Wounding = 'DART04'
        Asps_Nest = 'DART05'
        Giant_Rock = 'DART06'
        Crimson_Dart_PLUS3 = 'DART08'
        Darts_PLUS5 = 'STARDART'

    class DROW_ITEMS(Enum):

        Drow_Flail_PLUS3 = 'DWBLUN01'
        Drow_Bolt_of_Sleep = 'DWBOLT01'
        Drow_Bolt_of_Stunning = 'DWBOLT02'
        Drow_Bolt_PLUS1 = 'DWBOLT03'
        Drow_Elven_Chain_PLUS3 = 'DWCHAN01'
        Drow_Adamantine_Chain_PLUS5 = 'DWCHAN02'
        Drow_Piwafwi_Cloak = 'DWCLCK01'
        Adamantine_Dust = 'DWDUST'
        Drow_Halberd_PLUS3 = 'DWHALB01'
        Drow_Full_Plate_PLUS5 = 'DWPLAT01'
        Drow_Shield_PLUS3 = 'DWSHLD01'
        Drow_Lance_PLUS3 = 'DWSPER01'
        Drow_Scimitar_PLUS3 = 'DWSW1H01'
        Drow_Longsword_PLUS3 = 'DWSW1H02'
        Drow_Crossbow_of_Speed = 'DWXBOW01'

    class FAMILIARS(Enum):

        A_familiar_cat = 'FAMCAT'
        Upgraded_Cat = 'FAMCAT25'
        A_familiar_dust_mephit = 'FAMDUST'
        Upgraded_Dust_Mephit = 'FAMDUS25'
        A_familiar_fairy_dragon = 'FAMFAIR'
        Upgraded_fairy_dragon = 'FAMFAI25'
        A_familiar_ferret = 'FAMFER'
        Upgraded_ferret = 'FAMFER25'
        A_familiar_imp = 'FAMIMP'
        Upgraded_imp = 'FAMIMP25'
        A_familiar_pseudodragon = 'FAMPSD'
        Upgraded_pseudodragon = 'FAMPSD25'
        A_familiar_quasit = 'FAMQUAS'
        Upgraded_quasit = 'FAMQUA25'
        A_familiar_rabbit = 'FAMRAB'
        Upgraded_rabbit = 'FAMRAB25'

    class HALBERDS(Enum):

        Halberd = 'HALB01'
        Halberd_PLUS1 = 'HALB02'
        Halberd_PLUS2 = 'HALB03'
        Halberd_PLUS3_Dragons_Bane = 'HALB04'
        Halberd_PLUS4_Dragons_Breath = 'HALB05'
        Halberd_PLUS4_Blackmist = 'HALB06'
        Halberd_PLUS2_1 = 'HALB07'
        Halberd_PLUS2_Duskblade = 'HALB08'
        Wave_Halberd_PLUS4 = 'HALB09'
        Wave_Shaft = 'HALB09A & HALB09B'
        Ravager_PLUS4 = 'HALB10'
        Ravager_PLUS6 = 'HALB11'
        Halberd_PLUS3 = 'HALB12'

    class HAMMERS(Enum):

        War_Hammer = 'HAMM01'
        War_Hammer_PLUS1 = 'HAMM02'
        War_hammer_PLUS2 = 'HAMM03'
        Warhammer_PLUS1PLUS4_vs_giant_humanoids = 'HAMM04'
        War_Hammer_PLUS2 = 'HAMM05'
        Dwarven_Thrower_PLUS3 = 'HAMM06'
        Dwarven_Warhammer_of_Thunderbolts_PLUS3 = 'HAMM07'
        War_Hammer_PLUS2_1 = 'HAMM08'
        Crom_Faeyr = 'HAMM09'
        Runehammer_PLUS4 = 'HAMM10'
        Runehammer_PLUS5 = 'HAMM11'
        War_Hammer_PLUS3 = 'HAMM12'

    class HELMS(Enum):

        Helmet = 'HELM01'
        Helm_of_Opposite_Alignment = 'HELM02'
        Helm_of_Glory = 'HELM03'
        Helm_of_Defense = 'HELM04'
        Helm_of_Infravision = 'HELM05'
        Helm_of_Charm_Protection = 'HELM06'
        Helm_of_Balduran = 'HELM07'
        Helmet_1 = 'HELM08 through HELM13, HELM15'
        Kiels_Helmet = 'HELM14'
        Helm_of_Brilliance = 'HELM16'
        Skull_of_Death = 'HELM17'
        Pearly_White_Ioun_Stone = 'HELM18'
        Dusty_Rose_Ioun_Stone = 'HELM19'
        Pale_Green_Ioun_Stone = 'HELM20'
        Dragon_Helm = 'HELM21'
        Amnish_Helmet = 'HELM22'
        Golden_Ioun_Stone = 'HELM23'
        Obsidian_Ioun_Stone = 'HELM24'
        Silver_Ioun_Stone = 'HELM25'
        Lavender_Ioun_Stone = 'HELM26'
        Bronze_Ioun_Stone = 'HELM27'
        Circlet_of_Netheril_1 = 'HELM28'
        Thieves_Hood = 'HELM29'
        Thieves_Hood_1 = 'HELM30'
        Helm_of_the_Rock = 'HELM31'
        Helm_of_the_Rock_1 = 'HELM32'
        Gold_Horned_Helm = 'HELM33'
        Wong_Feis_Ioun_Stone = 'HELM34'
        Hrothgars_Axe_PLUS3 = 'WAAXE'
        Defender_of_Easthaven_PLUS2 = 'WAFLAIL'
        Jerrods_Mace = 'WAMACE'
        Scarlet_NinjaTo_PLUS3 = 'WANINJA'
        Jorils_Dagger_PLUS3 = 'WAS2H'
        Sling_of_Everard_PLUS5 = 'WASLING'
        Spear_of_Kuldahar_PLUS3 = 'WASPEAR'
        Staff_of_Arundel = 'WASTAFF'
        Everards_Morning_Star_PLUS2 = 'WASTAR'
        Kachikos_Wakizashi_PLUS3 = 'WAWAK'

    class KEYS(Enum):

        MaeVars_Strongbox_Key = 'EDWINKEY'
        Cult_Key = 'KEY01'
        Gaals_Key = 'KEY02'
        Planar_Key = 'KEY03'
        Sun_Ray_Symbol = 'KEY04'
        Dawns_Light_Symbol = 'KEY05'
        Lightstone_Symbol = 'KEY06'
        Chapel_Key = 'KEY07'
        Chain_Key = 'KEY08'
        Firkraag_Prison_Key = 'KEY09'
        Keep_Key = 'KEY10'
        Planar_Prison_Cell_Key = 'KEY11'
        Key_to_Arans_Lair = 'KEY12'
        Shadow_Thief_Prison_Key = 'KEY13'
        Piece_of_Burial_Mask = 'KEY14'
        Piece_of_Burial_Mask_1 = 'KEY15'
        Piece_of_Burial_Mask_2 = 'KEY16'
        Piece_of_Burial_Mask_3 = 'KEY17'
        Piece_of_Burial_Mask_4 = 'KEY18'
        Piece_of_Burial_Mask_5 = 'KEY19'
        Burial_Mask_of_King_Strohm_III = 'KEY20'
        Samias_Key = 'KEY21'
        Shadow_Prison_Key = 'KEY22'
        Symbol_of_Amaunator = 'KEY23'
        Sahuagin_Treasury_Key = 'KEY24'
        Despana_Treasury_Key = 'KEY25'
        Sekolahs_Tooth = 'KEY26'
        Guildhouse_Key = 'KEY27'
        Jons_Key = 'KEY28'
        Sewer_Key = 'KEY29'
        Outer_Jail_Door_Key = 'SARKEY01'
        Secret_Jail_Door_Key = 'SARKEY02'
        Sealed_Door_Key_Saradush_Prison = 'SARKEY03'
        Sewer_Key_Saradush = 'SARKEY04'
        Drow_Guards_Key = 'SENKEY01'
        Drow_Wardstone = 'SENKEY02'
        Sendais_Key = 'SENKEY03'

    class LEATHER_ARMORS(Enum):

        Leather_Armor = 'LEAT01'
        Leather_Armor_PLUS1 = 'LEAT02'
        Leather_Armor_PLUS2 = 'LEAT03'
        Studded_Leather_Armor = 'LEAT04'
        Studded_Leather_Armor_PLUS1 = 'LEAT05'
        Studded_Leather_Armor_PLUS2_missile_attraction = 'LEAT06'
        Studded_Leather_Armor_PLUS2 = 'LEAT07'
        Shadow_Armor = 'LEAT08'
        Leather_Armor_PLUS3 = 'LEAT09'
        Hide_Armor = 'LEAT10'
        Leather_Armor_PLUS2_1 = 'LEAT11'
        Leather_Armor_PLUS3_1 = 'LEAT12'
        Skin_of_the_Ghoul_PLUS4 = 'LEAT13'
        The_Nights_Gift_PLUS5 = 'LEAT14'
        Studded_Leather_Armor_PLUS2_1 = 'LEAT15'
        Orc_Leather_PLUS3 = 'LEAT16'
        Armor_of_Deep_Night_PLUS4 = 'LEAT17'
        Armor_of_the_Viper_PLUS5 = 'LEAT18'
        Shadow_Dragon_Scale = 'LEAT19'
        Aegers_Hide_PLUS3 = 'LEAT20'
        Human_Flesh_PLUS5 = 'LEAT21'
        Human_Flesh = 'LEAT22'
        Studded_Leather_of_Thorns_PLUS6 = 'LEAT23'
        Grandmasters_Armor_PLUS6 = 'LEAT24'

    class MISC(Enum):

        Aeries_Baby = 'AERIEBAB'
        Mallas_Soul_Stone = 'AMSOUL01'
        Summons_Cespenar = 'BOTSMITH'
        The_Lanthorn = 'C6LANTHO'
        Deck_of_Many_Things = 'DECK'
        Shakti_Figurine = 'FIGURE01'
        Blue_Globes = 'GLOBBLU1 to GLOBBLU4'
        Red_Globes = 'GLOBRED1 to GLOBRED4'
        Green_Globes = 'GLOBGRE1 to GLOBGRE4'
        Purple_Globes = 'GLOBPUR1 to GLOBPUR4'
        Ring_of_Invisibility = 'MAGE01'
        Ring_of_Barkskin = 'MAGE02'
        Ring_of_Mirror_Image = 'MAGE03'
        Pseudo_Ring_of_Blur = 'MAGE04'
        Pseudo_Ring_of_Free_Action = 'MAGE05'

    class Exceptions(Enum):

        Winter_Wolf_Pelt = 'MISC01'
        Mirror = 'MISC02'
        Small_Box = 'MISC03'
        Bassilus_Holy_Symbol = 'MISC04'
        Gold_Piece = 'MISC07'
        Ankheg_Shell = 'MISC12'
        Samuel = 'MISC13'
        Fire_Agate_Gem = 'MISC16'
        Lynx_Eye_Gem = 'MISC17'
        Sunstone_Gem = 'MISC18'
        Turquoise_Gem = 'MISC19'
        Bottle_of_Wine = 'MISC1A'
        Butter_Knife_of_Balduran = 'MISC1B'
        Sea_Charts = 'MISC1C'
        Evans_Body = 'MISC1E'
        Dradeels_Spell_Book = 'MISC1F'
        Farthings_Dolly = 'MISC1G'
        Gong_Mallet = 'MISC1H'
        Belladonna_flowers = 'MISC1I'
        Glittering_Beljuril_Gemstone = 'MISC1J'
        Bloodstone_Gem = 'MISC20'
        Skydrop_Gem = 'MISC21'
        Andar_Gem = 'MISC22'
        Jasper_Gem = 'MISC23'
        Tchazar_Gem = 'MISC24'
        Zircon_Gem = 'MISC25'
        Iol_Gem = 'MISC26'
        Moonstone_Gem = 'MISC27'
        Waterstar_Gem = 'MISC28'
        Ziose_Gem = 'MISC29'
        Doppelganger_Wardstone = 'MISC2A'
        Level_1_Exit_Wardstone = 'MISC2B'
        Islanne_Wardstone = 'MISC2C'
        Kiel_Wardstone = 'MISC2D'
        Fuernebol_Wardstone = 'MISC2E'
        Teleportation_Wardstone = 'MISC2F'
        Level_2_Exit_Wardstone = 'MISC2G'
        Wardstone_Forgery = 'MISC2I'
        Compass_Wardstone = 'MISC2K'
        Bone_Wardstone = 'MISC2L'
        Dwarven_Rune_1_Wardstone = 'MISC2M'
        Dwarven_Rune_2_Wardstone = 'MISC2N'
        Lock_of_hair_from_Kirinhale = 'MISC2O'
        Harp_of = 'MISC2P'
        Chrysoberyl_Gem = 'MISC30'
        Star_Diopside_Gem = 'MISC31'
        Shandon_Gem = 'MISC32'
        Aquamarine_Gem = 'MISC33'
        Garnet_Gem = 'MISC34'
        Horn_Coral_Gem = 'MISC35'
        Pearl = 'MISC36'
        Sphene_Gem = 'MISC37'
        Black_Opal = 'MISC38'
        Water_Opal = 'MISC39'
        Book_of_Infinite_Spells = 'MISC3A'
        Book_of_Infinite_Spells_1 = 'MISC3A1'
        Book_of_Infinite_Spells_2 = 'MISC3A2'
        Book_of_Infinite_Spells_3 = 'MISC3A3'
        Book_of_Infinite_Spells_4 = 'MISC3A4'
        Book_of_Infinite_Spells_5 = 'MISC3A5'
        Book_of_Infinite_Spells_6 = 'MISC3A6'
        Book_of_Infinite_Spells_7 = 'MISC3A7'
        Book_of_Infinite_Spells_8 = 'MISC3A8'
        Book_of_Infinite_Spells_9 = 'MISC3A9'
        Efreeti_Bottle = 'MISC3C'
        Golden_Lion_Figurine = 'MISC3D'
        Black_Spider_Figurine = 'MISC3E'
        Jade_Hound = 'MISC3F'
        Horn_of_Blasting = 'MISC3H'
        Silver_Horn_of_Valhalla = 'MISC3I'
        Bronze_Horn_of_Valhalla = 'MISC3J'
        Iron_Horn_of_Valhalla = 'MISC3K'
        Horn_of_Silence = 'MISC3L'
        Harp_of_Discord = 'MISC3M'
        Azlaers_Harp = 'MISC3N'
        Methilds_Harp = 'MISC3O'
        Glasses_of_Identification = 'MISC3P'
        Moonbar_Gem = 'MISC40'
        Star_Sapphire = 'MISC41'
        Diamond = 'MISC42'
        Emerald = 'MISC43'
        Kings_Tears = 'MISC44'
        Rogue_Stone = 'MISC45'
        Golden_Pantaloons = 'MISC47'
        Idol = 'MISC48'
        Melicamp_the_Chicken = 'MISC49'
        Activation_Stone = 'MISC4A'
        Jail_Cell_Key = 'MISC4B'
        Air_Elemental_Statue = 'MISC4C'
        The_Genies_Flask = 'MISC4D'
        Energy_Cells = 'MISC4E'
        Portal_Key = 'MISC4G'
        Wand_of_Fire_Key = 'MISC4H'
        Wand_of_Frost_Key = 'MISC4I'
        Wand_of_Summoning_Key = 'MISC4J'
        Wand_of_Lightning_Key = 'MISC4K'
        Wand_of_Cloudkill_Key = 'MISC4L'
        Wand_of_Missiles_Key = 'MISC4M'
        Acorns = 'MISC4N'
        Sewage_Golem_Key = 'MISC4O'
        Key_to_Frennedans_Room = 'MISC4P'
        The_Ogres_Sword = 'MISC4Q'
        Haegans_Key = 'MISC4R'
        Key_to_Shadow_Thieves_Cellar = 'MISC4S'
        Letter_of_Transfer = 'MISC4T'
        Embarls_Dagger = 'MISC4U'
        MaeVars_Letter = 'MISC4V'
        Edwins_Documents = 'MISC4W'
        Statuette_of_Lathander = 'MISC4X'
        Necklace_of_Talos = 'MISC4Y'
        Beastmaster_Key = 'MISC4Z'
        Skull = 'MISC50'
        Lock_of_Nymphs_Hair = 'MISC51'
        Wyvern_Head = 'MISC52'
        Bowl_of_Water_Elemental_Control = 'MISC53'
        Childs_Body = 'MISC54'
        Duke_Eltans_Body = 'MISC55'
        Broken_Weapon = 'MISC56'
        Broken_Shield = 'MISC57'
        Broken_Armor = 'MISC58'
        Broken_Miscellaneous = 'MISC59'
        Rift_Device_Part = 'MISC5A'
        Rift_Device_Part_2 = 'MISC5B'
        Rift_Device = 'MISC5C'
        Harper_Bird = 'MISC5D'
        Harper_Amulet = 'MISC5E'
        Renfelds_Body = 'MISC5F'
        Exotic_Hide = 'MISC5G'
        Guril_Berries = 'MISC5H'
        Amsis_Key = 'MISC5I'
        Writ_of_Innocence = 'MISC5J'
        Illithium_Ore = 'MISC5K'
        Littleman_The_Stuffed_Bear = 'MISC5L'
        Inspectors_Body = 'MISC5M'
        Piece_of_Red_Cloth = 'MISC5N'
        Silver_Pantaloons = 'MISC5O'
        Ransom_Note = 'MISC5P'
        Blood_of_Quallos_Friend = 'MISC5Q'
        The_Lovers_Ring = 'MISC5R'
        Hand = 'MISC5S'
        Shamans_Staff = 'MISC5T'
        Montarons_Body = 'MISC5U'
        Lock_of_Jaheiras_Hair = 'MISC5V'
        Keepsake_Locket = 'MISC5W'
        Harper_Pin = 'MISC5X'
        Jaheiras_Note = 'MISC5Y'
        Rift_Device_1 = 'MISC5Z'
        Spider_Body = 'MISC60'
        Bottle_of_Wine_1 = 'MISC61'
        Dead_Cat = 'MISC62'
        Chew_Toy = 'MISC63'
        Telescope = 'MISC64'
        Brages_Body = 'MISC65'
        Farmer_Bruns_son = 'MISC66'
        Bruns_Dead_Son = 'MISC67'
        Abela_the_Nymph = 'MISC68'
        Helsharas_Artifact_Fragment = 'MISC69'
        Tanners_Letter = 'MISC6A'
        Dennis_Mothers_Gong = 'MISC6B'
        Guril_Berries_1 = 'MISC6C'
        Solik_Berries = 'MISC6D'
        Oak_Bark = 'MISC6E'
        Quataris_Confession = 'MISC6F'
        Bust_of_Sune = 'MISC6G'
        Mekraths_Mirror = 'MISC6H'
        Anargs_Cup = 'MISC6I'
        Golem_Head = 'MISC6J'
        Golem_Arm = 'MISC6K'
        Golem_Brain = 'MISC6L'
        Demon_Heart = 'MISC6M'
        Sun_Gem = 'MISC6N'
        Sun_Gem_1 = 'MISC6O'
        Shadow_Dragon_Wardstone = 'MISC6P'
        Amuanas_Bones = 'MISC6Q'
        Note_to_Order = 'MISC6R'
        Chunk_of_Illithium_Alloy = 'MISC6S'
        Planar_Stone = 'MISC6T'
        Firkraags_Challenge = 'MISC6U'
        Smuggled_Shipment = 'MISC6V'
        Wooden_Stake = 'MISC6W'
        Portal_Gem = 'MISC6X'
        Mimics_Blood = 'MISC6Y'
        Beljuril = 'MISC6Z'
        Delornas_Statue = 'MISC70'
        Delornas_Spellbook = 'MISC71'
        The_Claw_of_Kazgaroth = 'MISC72'
        The_Horn_of_Kazgaroth = 'MISC73'
        The_Candle = 'MISC74'
        Dagger_of_Venom_1 = 'MISC75'
        The_Dream_Potion = 'MISC76'
        Skull_of_Kereph = 'MISC77'
        Invitation = 'MISC78'
        Female_Body = 'MISC79'
        Chicken = 'MISC7A'
        Chicken_1 = 'MISC7B'
        Contacts_Note = 'MISC7C'
        Barls_Antidote = 'MISC7D'
        Fairy_Dust = 'MISC7E'
        TiVaels_Head = 'MISC7F'
        Jaheiras_note_for = 'MISC7G'
        Umar_Witch_Project_Journal = 'MISC7H'
        Chaos_Tome = 'MISC7I'
        Wand_of_Activation = 'MISC7J'
        Head_of_Cotirso = 'MISC7K'
        Valygars_Body = 'MISC7L'
        Corthala_Tax_Notice = 'MISC7M'
        Wand_of_Lightning = 'MISC7N'
        Note = 'MISC7O'
        Tombelthens_Journal = 'MISC7P'
        Tombelthens_Journal_1 = 'MISC7Q'
        Mithril_Medallion = 'MISC7R'
        Lord_Tombelthens_Note = 'MISC7S'
        Moon_Dog_Figurine = 'MISC7T'
        Dog_Stew = 'MISC7U'
        Dog_Meat = 'MISC7V'
        Lavoks_Tome = 'MISC7W'
        Mastery_Orb = 'MISC7X'
        Thrall_Collar = 'MISC7Y'
        Coal = 'MISC7Z'
        Male_Body = 'MISC80'
        Ancient_Armor = 'MISC82'
        Key_to_River_Plug = 'MISC83'
        Boo = 'MISC84'
        Mulaheys_Holy_Symbol = 'MISC85'
        Bandit_Scalp = 'MISC86'
        Contaminated_Iron = 'MISC87'
        Rabbits_Foot = 'MISC88'
        Edwins_Amulet = 'MISC89'
        Note_1 = 'MISC8A'
        Note_2 = 'MISC8B'
        Morn_Ritual = 'MISC8C'
        Noontide_Ritual = 'MISC8D'
        Dusk_Ritual = 'MISC8E'
        Playhouse_Deed = 'MISC8F'
        Rune_of_Imprisonment = 'MISC8G'
        Blood_of_a_Silver_Dragon = 'MISC8H'
        Note_from_Imnesvale = 'MISC8I'
        Boots_of_the_West = 'MISC8J'
        Ihtafeers_head = 'MISC8K'
        Mantle_of_Waukeen = 'MISC8L'
        Trademeet_Tomb_Key = 'MISC8M'
        Isaeas_Financial_Statements = 'MISC8N'
        Isaeas_Signet_Ring = 'MISC8O'
        Isaeas_Slavery_Document = 'MISC8P'
        Rebels_Orb = 'MISC8Q'
        Fake_Rebels_Heart = 'MISC8R'
        Rebels_Heart = 'MISC8S'
        Cernds_Baby = 'MISC8T'
        Silver_Blade = 'MISC8U'
        Wardstone_for_Asylum = 'MISC8V'
        Opal_Stone = 'MISC8W'
        Ruby_Stone = 'MISC8X'
        Sapphire_Stone = 'MISC8Y'
        Kurtulmaks_Crystal_Shard = 'MISC8Z'
        Chelaks_Body = 'MISC90'
        Grapes = 'MISC91'
        Switch_for_engine = 'MISC92'
        Odd_looking_key = 'MISC93'
        Mallet_head = 'MISC94'
        Mallet_handle = 'MISC95'
        Peladon = 'MISC96'
        DeTranions_Baalor_ale = 'MISC97'
        Durlags_goblet = 'MISC98'
        Cursed_Plate_mail_armor = 'MISC99'
        The_Hand_of_Dace = 'MISC9A'
        Vampire_Stake = 'MISC9B'
        Liums_Journal_of_Malevolent_Magicks = 'MISC9C'
        Giant_Trolls_Head = 'MISC9D'
        Minotaur_Horn = 'MISC9E'
        Minotaur_Horn_2 = 'MISC9F'
        Pirate_Horn = 'MISC9G'
        Nebs_Head = 'MISC9H'
        First_journal_of_Jon_Irenicus = 'MISC9I'
        Second_journal_of_Jon_Irenicus = 'MISC9J'
        Third_journal_of_Irenicus = 'MISC9K'
        Deed_to_the_Windspear_Hills = 'MISC9L'
        Pipe = 'MISC9M'
        Pendant = 'MISC9N'
        Staff = 'MISC9O'
        Helmet_2 = 'MISC9P'
        Scimitar = 'MISC9Q'
        Light_Gem = 'MISC9R'
        Mind_Amplification_Device = 'MISC9S'
        Dragon_Eggs = 'MISC9T'
        Fake_Dragon_Eggs = 'MISC9U'
        Fake_Dragon_Eggs_1 = 'MISC9V'
        Drow_Piwafwi_Cloak_1 = 'MISC9W'
        Control_Circlet = 'MISC9X'
        Brine_Potion = 'MISC9Y'
        Corrupted_Tadpoles = 'MISC9Z'
        Gem = 'MISCA1'
        Sulphurous_Poison = 'MISCA2'
        Book_of_Rituals = 'MISCA3'
        Potion_of_Squirrel_Change = 'MISCA4'
        Stoneshape_Scroll = 'MISCA5'
        Patrol_Leaders_Helmet = 'MISCA6'
        KuoToans_Blood = 'MISCA7'
        Eyestalk_of_an_Elder_Orb = 'MISCA8'
        Star_Medallion = 'MISCA9'
        Golden_Circlet = 'MISCAA'
        Jar_of_Water = 'MISCAB'
        Sundial = 'MISCAC'
        Sun_Medallion = 'MISCAD'
        Sword_Medallion = 'MISCAE'
        The_Gagged_Man = 'MISCAF'
        Mirror_1 = 'MISCAG'
        Hourglass = 'MISCAH'
        Worn_Out_Boots_1 = 'MISCAI'
        Grinning_Skull = 'MISCAJ'
        Wardens_Note = 'MISCAK'
        Mithril_Token = 'MISCAL'
        Galvenas_Key = 'MISCAM'
        Galvenas_Medallion = 'MISCAN'
        Mind_Flayer_Painting = 'MISCAO'
        Umberhulk_Painting = 'MISCAP'
        Troll_Painting = 'MISCAQ'
        Djinni_Painting = 'MISCAR'
        Sleeping_Draught = 'MISCAS'
        Mug_of_Ale = 'MISCAT'
        Elven_Holy_Water = 'MISCAU'
        Golden_Skull = 'MISCAV'
        Golden_Arm_and_Leg = 'MISCAW'
        Golden_Leg = 'MISCAX'
        Golden_Torso = 'MISCAY'
        Beholder_Eye = 'MISCAZ'
        Talisman_of_Rillifane = 'MISCB1'
        Golden_Goblet_of_Life = 'MISCB2'
        Moonblade = 'MISCB3'
        Tree_of_Life_Nuts = 'MISCB4'
        Tears_of_Bhaal = 'MISCB5'
        Tears_of_Bhaal_1 = 'MISCB6'
        Tears_of_Bhaal_2 = 'MISCB7'
        Tears_of_Bhaal_3 = 'MISCB8'
        Tears_of_Bhaal_4 = 'MISCB9'
        Tears_of_Bhaal_5 = 'MISCBA'
        Blackrazor_Long_Sword_PLUS3 = 'MISCBC'
        Dog_Bones = 'MISCBD'
        Gilded_Rope = 'MISCBE'
        Jaellat_Wardstone = 'MISCBF'
        Lichs_Tooth = 'MISCBG'
        Deirexs_Gem = 'MISCBH'
        Magical_Rope = 'MISCBI'
        Qilues_Brain = 'MISCBJ'
        Illithid_Serum = 'MISCBK'
        Aeries_Body = 'MISCBL'
        Anomens_Body = 'MISCBM'
        Jaheiras_Body = 'MISCBN'
        Viconias_Body = 'MISCBO'
        Bodhis_Black_Heart = 'MISCBP'
        Tree_of_Life_Nuts_1 = 'MISCBQ'
        Stone_Harp = 'MISCBR'
        Stone_Horn = 'MISCBS'
        Elven_Priest_Stone = 'MISCBT'
        Yoshimos_Heart = 'MISCBU'
        Elder_Brain_Blood = 'MISCBV'
        Sahuagin_Scribes_Notes = 'MISCBW'
        Note_3 = 'MISCBX'
        Tainted_Dragon_Eggs = 'MISCBY'
        Tizzaks_Journal = 'MISCBZ'
        Demins_Note = 'MISCCA'
        Bronze_Pantalettes = 'MISCCB'
        Drow_Note_of_Gate_Sundering = 'MISCCC'
        Jansen_Spectroscopes = 'NPMISC1'
        Jansen_TechnoGloves = 'NPMISC2'

    class FULL_PLATE_ARMORS(Enum):

        Plate_Mail_Armor = 'PLAT01'
        Plate_Mail_PLUS1 = 'PLAT02'
        Full_Plate_Mail = 'PLAT04'
        Full_Plate_Mail_PLUS1 = 'PLAT05'
        Ankheg_Plate_Mail = 'PLAT06'
        Plate_Mail = 'PLAT07'
        Plate_Mail_PLUS3 = 'PLAT08'
        Mithral_Field_Plate_Armor_PLUS2 = 'PLAT09'
        Plate_Mail_PLUS1_1 = 'PLAT10'
        Delvers_Plate_PLUS2 = 'PLAT11'
        Doomplate_PLUS3 = 'PLAT12'
        Gorgon_Plate_PLUS4 = 'PLAT13'
        Full_Plate_Mail_PLUS1_1 = 'PLAT14'
        Pride_of_the_Legion_PLUS2 = 'PLAT15'
        Armor_of_the_Hart_PLUS3 = 'PLAT16'
        Trahcies_Plate_PLUS5 = 'PLAT17'
        Red_Dragon_Scale = 'PLAT18'
        Full_Plate_PLUS_2 = 'PLAT19'
        Blue_Dragon_Plate = 'PLAT20'
        Enkidus_Full_Plate_PLUS3 = 'PLAT21'
        Shuruppaks_Plate = 'PLAT22'
        Full_Plate_Mail_PLUS2 = 'PLAT23'
        Firecam_FullPlate_Armor = 'NPPLAT'

    class PLOT_ITEMS(Enum):

        Abazigals_Wardstone = 'BAZPLO01'
        Draconis_Head = 'BAZPL002'
        Yellow_Dragon_Eggs = 'BAZPLO03'
        Breath_Potion = 'BAZPLO04'
        Rope = 'BAZPLO05'
        Reversal_Scroll = 'BAZPLO06'
        Empty_Breath_Potion_Flask = 'BAZPLO07'
        Gauth_Eyestalk = 'BAZPLO08'
        Still_Beating_Heart = 'HGHEART'
        Yaga_Shuras_Heart = 'HGHEART2'
        Flame_Wardstone = 'HGWARD01'
        Skull_Wardstone = 'HGWARD02'
        Hammer_Wardstone = 'HGWARD03'
        Blood_Wardstone = 'HGWARD04'
        Handwritten_Notes = 'LUM1 to LUM9'
        Ritual_Scroll = 'PLOT01A'
        Vigil_Stone = 'PLOT01B'
        Tattered_Parchment = 'PLOT01C'
        Tattered_Parchment_1 = 'PLOT01D'
        Tattered_Parchment_2 = 'PLOT01E'
        Candle = 'PLOT01F'
        Holy_Book = 'PLOT01G'
        Bell = 'PLOT01H'
        History_of_the_Imprisoned_One = 'PLOT01I'
        Wardstone = 'PLOT01J'
        Wardstone_1 = 'PLOT01K'
        Tinderbox = 'PLOT01L'
        Handwritten_Note = 'PLOT01M'
        Scribbled_Note = 'PLOT01N'
        Key = 'PLOT01O'
        Old_Slippers = 'PLOT01P'
        Helms_Scroll = 'PLOT01Q'
        Scepter_of_Radiance = 'PLOT02A'
        Scepter_of_Radiance_1 = 'PLOT02B'
        Scepter_Gem = 'PLOT02C'
        Scepter_Gem_1 = 'PLOT02D'
        Scepter_Gem_2 = 'PLOT02E'
        Madmans_Journal = 'PLOT02F'
        Journal = 'PLOT02G'
        Deck_of_Many_Things_1 = 'PLOT02H'
        Tahazzars_Heart = 'PLOT02I'
        Karashurs_Heart = 'PLOT02J'
        Air_Scepter = 'PLOT03A'
        Fire_Scepter = 'PLOT03B'
        Slime_Scepter = 'PLOT03C'
        Ice_Scepter = 'PLOT03D'
        Portal_Key_1 = 'PLOT03E'
        Air_Library_Note = 'PLOT03F'
        Fire_Library_Note = 'PLOT03G'
        Slime_Library_Note = 'PLOT03H'
        Ice_Library_Note = 'PLOT03I'
        Key_1 = 'PLOT03K'
        Blue_Oil = 'PLOT04A'
        Red_Oil = 'PLOT04B'
        Purple_Oil = 'PLOT04C'
        Crystal_Mallet = 'PLOT04D'
        Diary_of_Carstons_Apprentice = 'PLOT04E'
        Flint_and_Tinder = 'PLOT04F'
        Illithid_Rod = 'PLOT04G'
        Illithid_Rod_1 = 'PLOT04H'
        Illithid_Rod_2 = 'PLOT04I'
        Carstons_Journal = 'PLOT04J'
        Heart_Key = 'PLOT05A'
        Mind_Key = 'PLOT05B'
        Spirit_Key = 'PLOT05C'
        Warriors_Skull = 'PLOT05D'
        Bounty_Notice = 'PLOT16A'
        Note_4 = 'PLOT16B'
        Monastery_Gate_Key = 'PLOT17A'
        Graveyard_Key = 'PLOT17B'
        Lazarus_Teleport_Scroll = 'PLOT18A'
        Lazarus_Spellbook = 'PLOT18B'

    class POTIONS(Enum):

        Potion_of_Fire_Resistance = 'POTN02'
        Potion_of_Hill_Giant_Strength = 'POTN03'
        Potion_of_Frost_Giant_Strength = 'POTN04'
        Potion_of_Fire_Giant_Strength = 'POTN05'
        Potion_of_Cloud_Giant_Strength = 'POTN06'
        Potion_of_Storm_Giant_Strength = 'POTN07'
        Potion_of_Healing = 'POTN08'
        Potion_of_Heroism = 'POTN09'
        Potion_of_Invisibility = 'POTN10'
        Potion_of_Invulnerability = 'POTN11'
        Potion_of_Stone_Giant_Strength = 'POTN12'
        Oil_of_Firey_Burning = 'POTN13'
        Oil_of_Speed = 'POTN14'
        Red_Potion = 'POTN15'
        Violet_Potion = 'POTN16'
        Elixir_of_Health = 'POTN17'
        Potion_of_Absorption = 'POTN18'
        Potion_of_Agility = 'POTN19'
        Antidote = 'POTN20'
        Potion_of_Clarity = 'POTN21'
        Potion_of_Cold_Resistance = 'POTN22'
        Oil_of_Speed_1 = 'POTN23'
        Potion_of_Defense = 'POTN24'
        Potion_of_Healing_1 = 'POTN25'
        Potion_of_Explosions = 'POTN26'
        Potion_of_Firebreath = 'POTN27'
        Potion_of_Fortitude = 'POTN28'
        Potion_of_Genius = 'POTN29'
        Potion_of_Infravision = 'POTN30'
        Potion_of_Insulation = 'POTN31'
        Antidote_1 = 'POTN32'
        Potion_of_Magic_Blocking = 'POTN33'
        Potion_of_Magic_Protection = 'POTN34'
        Potion_of_Magic_Shielding = 'POTN35'
        Potion_of_Master_Thievery = 'POTN36'
        Potion_of_Mind_Focusing = 'POTN37'
        Potion_of_Mirrored_Eyes = 'POTN38'
        Potion_of_Perception = 'POTN39'
        Potion_of_Invulnerability_1 = 'POTN40'
        Potion_of_Power = 'POTN41'
        Potion_of_Regeneration = 'POTN42'
        Potion_of_Insight = 'POTN43'
        Potion_of_Strength = 'POTN44'
        Potion_of_Freedom = 'POTN45'
        Potion_of_Stone_Form = 'POTN46'
        Mareks_Antidote = 'POTN47'
        Vial_of_Mysterious_Liquid_used_in_Nashkel_mines_to = 'POTN48'
        Potion_of_Extra_Healing = 'POTN52'
        Festule_the_Alchemists_Potion = 'POTN53'
        Empty_Potion_Bottle = 'POTN54'
        Potion_of_Superior_Healing = 'POTN55'
        Rogues_Potion_of_Frost_Giant_Strength = 'POTN56'

    class QUIVERS(Enum):

        Quiver_of_Plenty_PLUS1 = 'QUIVER01'
        Case_of_Plenty_PLUS1 = 'QUIVER02'
        Quiver_of_Plenty_PLUS2 = 'QUIVER03'
        Case_of_Plenty_PLUS2 = 'QUIVER04'
        Bag_of_Plenty_PLUS1 = 'QUIVER05'
        Bag_of_Plenty_PLUS2 = 'QUIVER06'

    class RINGS(Enum):

        Holy_Symbol_of_Lathander = 'BELT12'
        Holy_Symbol_of_Helm = 'BELT13'
        Holy_Symbol_of_Talos = 'BELT14'
        Plain_Ring = 'RING01'
        Ring_of_Fire_Resistance = 'RING02'
        Ring_of_Animal_Friendship = 'RING03'
        Ring_of_Clumsiness = 'RING04'
        Ring_of_Invisibility_1 = 'RING05'
        Ring_of_Protection_PLUS1 = 'RING06'
        Ring_of_Protection_PLUS2 = 'RING07'
        Ring_of_Wizardry = 'RING08'
        Ring_of_Free_Action = 'RING09'
        Gold_Ring = 'RING10'
        Silver_Ring = 'RING11'
        Onyx_Ring = 'RING12'
        Jade_Ring = 'RING13'
        Greenstone_Ring = 'RING14'
        Bloodstone_Ring = 'RING15'
        Angel_Skin_Ring = 'RING16'
        Flamedance_Ring = 'RING17'
        Fire_Opal_Ring = 'RING18'
        Ruby_Ring = 'RING19'
        Ring_of_Energy = 'RING20'
        Ring_of_Infravision = 'RING21'
        Ring_of_Holiness = 'RING22'
        Ring_of_Folly = 'RING23'
        Koveras_Ring_of_Protection = 'RING25'
        Ring_of_Djinni_Summoning = 'RING26'
        Ring_of_Fire_Control = 'RING27'
        Ring_of_Air_Control = 'RING28'
        Ring_of_Earth_Control = 'RING29'
        Ring_of_Human_Influence = 'RING30'
        Ring_of_Regeneration = 'RING31'
        Ring = 'RING32'
        Ring_of_the_Ram = 'RING33'
        Ring_of_Spell_Turning = 'RING34'
        Ring_of_Lock_Picks = 'RING35'
        Ring_of_Danger_Sense = 'RING36'
        Storm_Ring = 'RING37'
        Dawn_Ring = 'RING38'
        Ring_of_Gaxx = 'RING39'
        Ring_of_Acuity = 'RING40'
        Ring_of_Protection_PLUS3 = 'RING41'
        Ring_of_Improved_Invisibility = 'RING42'
        Oaken_Ring = 'RING43'
        Heartwood_Ring = 'RING44'
        Delryn_Family_Ring = 'RING45'
        Ring_of_AntiVenom = 'RING46'
        DArnisse_Signet_Ring = 'NPRING01'

    class RODS(Enum):

        Rod_of_Absorption = 'RODS01'
        Rod_of_Lordly_Might = 'RODS02'
        Rod_of_Resurrection = 'RODS03'
        Rod_of_Smiting = 'RODS04'
        Rod_of_Terror = 'RODS05'
        Rod_of_Reversal = 'RODS06'

    class DRAGON_SCALES(Enum):

        Shadow_Dragon_Scales = 'SCALEB'
        Red_Dragon_Scales = 'SCALER'

    class SCROLLS(Enum):

        Greater_Restoration = 'RESTORE'
        Spell_Scroll = 'SCRL02'
        Protection_from_Acid = 'SCRL03'
        Protection_from_Cold = 'SCRL04'
        Protection_from_Electricity = 'SCRL05'
        Protection_from_Fire = 'SCRL06'
        Protection_from_Magic = 'SCRL07'
        Protection_from_Poison = 'SCRL08'
        Protection_from_Undead = 'SCRL09'
        Cursed_Scroll_of_Weakness = 'SCRL10'
        Cursed_Scroll_of_Clumsiness = 'SCRL11'
        Cursed_Scroll_of_Foolishness = 'SCRL12'
        Cursed_Scroll_of_Ugliness = 'SCRL13'
        Cursed_Scroll_of_Summon_Monster = 'SCRL14'
        Protection_from_Petrification = 'SCRL15'
        Cursed_Scroll_of_Petrification = 'SCRL16'
        Cursed_Scroll_of_Ailment = 'SCRL17'
        Cursed_Scroll_of_Stupidity = 'SCRL18'
        Agannazars_Scorcher = 'SCRL1B'
        Ghoul_Touch = 'SCRL1C'
        Clairvoyance = 'SCRL1D'
        Dispel_Magic = 'SCRL1E'
        Flame_Arrow = 'SCRL1F'
        Fireball = 'SCRL1G'
        Haste = 'SCRL1H'
        Hold_Person = 'SCRL1I'
        Invisibility_10_radius = 'SCRL1J'
        Lightning_Bolt = 'SCRL1K'
        Monster_Summoning_I = 'SCRL1L'
        NonDetection = 'SCRL1M'
        Protection_from_Normal_Missiles = 'SCRL1N'
        Slow = 'SCRL1O'
        Skull_Trap = 'SCRL1P'
        Vampiric_Touch = 'SCRL1Q'
        Dire_Charm = 'SCRL1S'
        Ghost_Armor = 'SCRL1T'
        Confusion = 'SCRL1U'
        Stoneskin = 'SCRL1V'
        Fireshield = 'SCRL1W'
        Ice_Storm = 'SCRL1X'
        Improved_Invisibility = 'SCRL1Y'
        Minor_Globe_of_Invulnerability = 'SCRL1Z'
        Monster_Summoning_II = 'SCRL2A'
        Stoneskin_1 = 'SCRL2B'
        Animate_Dead = 'SCRL2D'
        Cloudkill = 'SCRL2E'
        Cone_of_Cold = 'SCRL2F'
        Monster_Summoning_III = 'SCRL2G'
        Shadow_Door = 'SCRL2H'
        Letters = 'SCRL2I-SCRL3F'
        Vocalize = 'SCRL3G'
        Protection_from_Evil = 'SCRL3H'
        Letter = 'SCRL3I'
        Letter_1 = 'SCRL3Z'
        Cure_Serious_Wounds = 'SCRL56'
        Free_Action = 'SCRL58'
        Neutralize_Poison = 'SCRL59'
        Mental_Domination = 'SCRL5A'
        Defensive_Harmony = 'SCRL5B'
        Protection_from_Lightning = 'SCRL5C'
        Protection_from_Evil_10_radius = 'SCRL5D'
        Champions_Strength = 'SCRL5E'
        Chaotic_Commands = 'SCRL5F'
        Remove_Curse = 'SCRL5G'
        Emotion = 'SCRL5H'
        Greater_Malison = 'SCRL5I, SCRL5W'
        Otilukes_Resilient_Sphere = 'SCRL5J'
        Spirit_Armor = 'SCRL5K'
        Polymorph_Other = 'SCRL5L'
        Polymorph_Self = 'SCRL5M'
        Domination = 'SCRL5N'
        Hold_Monster = 'SCRL5O'
        Chaos = 'SCRL5P'
        Feeblemind = 'SCRL5Q'
        Protection_from_Electricity_1 = 'SCRL5T'
        Reflected_Image = 'SCRL5U'
        Fireball_1 = 'SCRL5Z'
        Cure_Critical_Wounds = 'SCRL61'
        Flame_Strike = 'SCRL62'
        Raise_Dead = 'SCRL63'
        Grease = 'SCRL66'
        Armor = 'SCRL67'
        Burning_Hands = 'SCRL68'
        Charm_Person = 'SCRL69'
        Find_Familiar = 'SCRL6D'
        Power_Word_Sleep = 'SCRL6E'
        Ray_of_Enfeeblement = 'SCRL6F'
        Minor_Spell_Deflection = 'SCRL6G'
        Protection_from_Fire_1 = 'SCRL6H'
        Protection_from_Cold_1 = 'SCRL6I'
        Spell_Thrust = 'SCRL6J'
        Detect_Illusion = 'SCRL6K'
        Hold_Undead = 'SCRL6L'
        Enchanted_Weapon = 'SCRL6M'
        Fireshield_1 = 'SCRL6N'
        Secret_Word = 'SCRL6O'
        Minor_Sequencer = 'SCRL6P'
        Teleport_Field = 'SCRL6Q'
        Spider_Spawn = 'SCRL6R'
        Spell_Immunity = 'SCRL6S'
        Protection_from_Normal_Weapons = 'SCRL6T'
        Breach = 'SCRL6U'
        Lower_Resistance = 'SCRL6V'
        Oracle = 'SCRL6W'
        Conjure_Lesser_Fire_Elemental = 'SCRL6X'
        Protection_from_Acid_1 = 'SCRL6Y'
        Phantom_Blade = 'SCRL6Z'
        Color_Spray = 'SCRL70'
        Blindness = 'SCRL71'
        Friends = 'SCRL72'
        Protection_from_Petrification_1 = 'SCRL73'
        Identify = 'SCRL75'
        Infravision = 'SCRL76'
        Magic_Missile = 'SCRL77'
        Protection_from_Evil_1 = 'SCRL78'
        Shield = 'SCRL79'
        Conjure_Lesser_Air_Elemental = 'SCRL7B'
        Conjure_Lesser_Earth_Elemental = 'SCRL7C'
        Minor_Spell_Turning = 'SCRL7D'
        Invisible_Stalker = 'SCRL7E'
        Globe_of_Invulnerability = 'SCRL7F'
        Tensers_Transformation = 'SCRL7G'
        Flesh_to_Stone = 'SCRL7H'
        Death_Spell = 'SCRL7I'
        Protection_from_Magic_1 = 'SCRL7J'
        Mislead = 'SCRL7K'
        Pierce_Magic = 'SCRL7L'
        True_Sight = 'SCRL7M'
        Protection_from_Magical_Weapons = 'SCRL7O'
        Power_Word_Silence = 'SCRL7P'
        Improved_Haste = 'SCRL7Q'
        Death_Fog = 'SCRL7R'
        Chain_Lightning = 'SCRL7S'
        Disintegrate = 'SCRL7T'
        Contingency = 'SCRL7U'
        Spell_Deflection = 'SCRL7V'
        Wyvern_Call = 'SCRL7W'
        Conjure_Fire_Elemental = 'SCRL7X'
        Conjure_Air_Elemental = 'SCRL7Y'
        Conjure_Earth_Elemental = 'SCRL7Z'
        Shocking_Grasp = 'SCRL80'
        Sleep = 'SCRL81'
        Chill_Touch = 'SCRL82'
        Chromatic_Orb = 'SCRL83'
        Larlochs_Minor_Drain = 'SCRL84'
        Blur = 'SCRL85'
        Detect_Evil = 'SCRL86'
        Detect_Invisibility = 'SCRL87'
        Horror = 'SCRL89'
        Carrion_Summons = 'SCRL8A'
        Summon_Nishruu = 'SCRL8B'
        Stone_to_Flesh = 'SCRL8C'
        Spell_Turning = 'SCRL8D'
        Protection_from_the_Elements = 'SCRL8E'
        Project_Image = 'SCRL8F'
        Ruby_Ray_of_Reversal = 'SCRL8G'
        Khelbens_Warding_Whip = 'SCRL8H'
        Cacofiend = 'SCRL8I'
        Mantle = 'SCRL8J'
        Spell_Sequencer = 'SCRL8L'
        Sphere_of_Chaos = 'SCRL8M'
        Delayed_Blast_Fireball = 'SCRL8N'
        Finger_of_Death = 'SCRL8O'
        Prismatic_Spray = 'SCRL8P'
        Power_Word_Stun = 'SCRL8Q'
        Mordenkainens_Sword = 'SCRL8R'
        Summon_Efreeti = 'SCRL8S'
        Summon_Djinni = 'SCRL8T'
        Summon_Hakeashar = 'SCRL8U'
        Control_Undead = 'SCRL8V'
        Mass_Invisibility = 'SCRL8W'
        Spell_Shield = 'SCRL8X'
        Protection_from_Energy = 'SCRL8Y'
        Simulacrum = 'SCRL8Z'
        Invisibility = 'SCRL90'
        Knock = 'SCRL91'
        Know_Alignment = 'SCRL92'
        Luck = 'SCRL93'
        Resist_Fear = 'SCRL94'
        Melfs_Acid_Arrow = 'SCRL95'
        Mirror_Image = 'SCRL96'
        Stinking_Cloud = 'SCRL97'
        Strength = 'SCRL98'
        Web = 'SCRL99'
        Pierce_Shield = 'SCRL9A'
        Summon_Fiend = 'SCRL9B'
        Improved_Mantle = 'SCRL9C'
        Spell_Trigger = 'SCRL9D'
        Incendiary_Cloud = 'SCRL9E'
        Symbol_Fear = 'SCRL9F'
        AbiDalzims_Horrid_Wilting = 'SCRL9G'
        Maze = 'SCRL9H'
        Power_Word_Blind = 'SCRL9J'
        Spell_Trap = 'SCRL9L'
        Spellstrike = 'SCRL9M'
        Gate = 'SCRL9N'
        Absolute_Immunity = 'SCRL9P'
        Chain_Contingency = 'SCRL9Q'
        Time_Stop = 'SCRL9R'
        Imprisonment = 'SCRL9S'
        Meteor_Swarm = 'SCRL9T'
        Power_Word_Kill = 'SCRL9U'
        Wail_of_the_Banshee = 'SCRL9V'
        Energy_Drain = 'SCRL9W'
        Black_Blade_of_Disaster = 'SCRL9X'
        Shapechange = 'SCRL9Y'
        Freedom = 'SCRL9Z'
        Wizard_Eye = 'SCRLA1'
        Deafness = 'SCRLA2'
        Glitterdust = 'SCRLA3'
        Limited_Wish = 'SCRLA4'
        Melfs_Minute_Meteors = 'SCRLA5'
        Spook = 'SCRLA6'
        Remove_Magic = 'SCRLA7'
        Contagion = 'SCRLA8'
        Scroll_of_Crom_Faeyr = 'SCRLAG'
        Ray_of_Enfeeblement_1 = 'SCRLAI'
        Farsight = 'SCRLAJ'
        Remove_Curse_1 = 'SCRLAK'
        Sunfire = 'SCRLAL'
        Symbol_Death = 'SCRLAM, SCRLAO'
        Symbol_Stun = 'SCRLAN'
        Bigbys_Clenched_Fist = 'SCRLB1'
        Bigbys_Crushing_Hand = 'SCRLB2'
        Wish = 'SCRLB4'
        Stone_to_Flesh_1 = 'SCRLPET'
        Greater_Restoration_1 = 'SCRLSD'
        Summon_Cow = 'SCRLZZ'

    class SECRET_PANTALOON_STUFF(Enum):

        Big_Metal_Rod = 'SECRET01'
        Pulse_Ammo = 'SECRET02'
        Frag_Grenade = 'SECRET03'
        Scorcher_Ammo = 'SECRET04'
        Big_Metal_Unit = 'SECRET05'

    class SHIELDS(Enum):

        Small_Shield = 'SHLD01'
        Small_Shield_PLUS1 = 'SHLD02'
        Medium_Shield = 'SHLD03'
        Medium_Shield_PLUS1 = 'SHLD04'
        Large_Shield = 'SHLD05'
        Large_Shield_PLUS1 = 'SHLD06'
        Large_Shield_PLUS1_PLUS4_vs_Missiles = 'SHLD07'
        Buckler = 'SHLD08'
        Buckler_1 = 'SHLD09'
        Buckler_2 = 'SHLD10'
        Small_Shield_1 = 'SHLD11'
        Small_Shield_2 = 'SHLD12'
        Medium_Shield_1 = 'SHLD13'
        Medium_Shield_2 = 'SHLD14'
        Large_Shield_1 = 'SHLD15'
        Large_Shield_2 = 'SHLD16'
        Buckler_PLUS1 = 'SHLD17'
        Large_Shield_3 = 'SHLD18'
        Large_Shield_PLUS2 = 'SHLD19'
        Kiels_Buckler = 'SHLD20'
        Dragon_Scale_Shield_PLUS2 = 'SHLD21'
        Sentinel_PLUS4 = 'SHLD22'
        Fortress_Shield_PLUS3 = 'SHLD23'
        Reflection_Shield_PLUS1 = 'SHLD24'
        Shield_of_Harmony_PLUS2 = 'SHLD25'
        Shield_of_the_Lost_PLUS2 = 'SHLD26'
        Saving_Grace_PLUS3 = 'SHLD27'
        Small_Shield_PLUS2 = 'SHLD28'
        Medium_Shield_PLUS2 = 'SHLD29'
        Large_Shield_PLUS2_1 = 'SHLD30'
        Darksteel_Shield_PLUS4 = 'SHLD31'
        Shield_of_the_Order_PLUS4 = 'SHLD32'
        Delryn_Family_Shield = 'NPSHLD'

    class SLINGS(Enum):

        Sling = 'SLNG01'
        Sling_PLUS1 = 'SLNG02'
        Sling_PLUS3 = 'SLNG03'
        Sling_PLUS2 = 'SLNG04'
        Sling_PLUS3__Arlas_Dragonbane = 'SLNG05'
        Sling_of_Arvoreen_PLUS4 = 'SLNG06'
        Sling_of_Seeking_PLUS2 = 'SLNG07'
        Erinne_Sling_PLUS4 = 'SLNG08'
        Erinne_Sling_PLUS5 = 'SLNG09'
        Sling_PLUS3_1 = 'SLNG10'

    class SPEARS(Enum):

        Spear = 'SPER01'
        Spear_PLUS1 = 'SPER02'
        Spear_PLUS3_Backbiter = 'SPER03'
        Spear_1 = 'SPER04'
        Spear_PLUS2 = 'SPER05'
        Spear_PLUS3 = 'SPER06'
        Spear_of_the_Unicorn_PLUS2 = 'SPER07'
        Spear_PLUS3_Impaler = 'SPER08'
        Spear_PLUS1_Halcyon = 'SPER09'
        Spear_of_Withering_PLUS4 = 'SPER10'
        Ixils_Nail_PLUS4 = 'SPER11'
        Ixils_Spike_PLUS6 = 'SPER12'

    class STAVES(Enum):

        Staff_of_the_Ram_PLUS4 = 'AURSTAF'
        Quarterstaff = 'STAF01'
        Quarterstaff_PLUS1 = 'STAF02'
        Quarterstaff_1 = 'STAF03'
        Quarterstaff_2 = 'STAF04'
        Staff_of_Striking = 'STAF05'
        Staff_Mace = 'STAF06'
        Staff_Spear_PLUS2 = 'STAF07'
        Quarterstaff_PLUS3 = 'STAF08'
        Staff_of_Command = 'STAF09'
        Staff_of_Curing = 'STAF10'
        Staff_of_the_Magi = 'STAF11'
        Staff_of_Power = 'STAF12'
        Staff_of_Thunder_and_Lightning_PLUS2 = 'STAF13'
        Staff_of_the_Woodlands_PLUS4 = 'STAF14'
        Staff_of_Air_PLUS2 = 'STAF15'
        Staff_of_Earth_PLUS2 = 'STAF16'
        Staff_of_Fire_PLUS2 = 'STAF17'
        Quarter_Staff_PLUS2 = 'STAF18'
        Clerics_Staff_PLUS3 = 'STAF19'
        Staff_of_Rynn_PLUS4 = 'STAF20'
        Staff_of_the_Ram_PLUS4_1 = 'STAF21'
        Staff_of_the_Ram_PLUS6 = 'STAF22'
        Serpent_Shaft = 'STAF23'
        Quarter_Staff_PLUS3 = 'STAF24'
        Staff_of_the_High_Forest = 'NPSTAF'

    class ONE_HANDED_SWORDS(Enum):

        Bastard_Sword = 'SW1H01'
        Bastard_Sword_PLUS1 = 'SW1H02'
        Bastard_Sword_PLUS1_PLUS3_vs_Shapeshifters = 'SW1H03'
        Long_Sword = 'SW1H04'
        Long_Sword_PLUS1 = 'SW1H05'
        Long_Sword_PLUS2 = 'SW1H06'
        Short_Sword = 'SW1H07'
        Short_Sword_PLUS1 = 'SW1H08'
        Short_Sword_PLUS2 = 'SW1H09'
        Short_Sword_of_Backstabbing = 'SW1H10'
        Odd_Flame_Sword_Creature_Attack = 'SW1H11'
        Hulls_Long_Sword = 'SW1H12'
        Moonblade_1 = 'SW1H13'
        Short_Sword_PLUS1_1 = 'SW1H14'
        Scimitar_PLUS3_Frostbrand = 'SW1H15'
        Scimitar_PLUS5_Defender = 'SW1H16'
        Perdues_Short_Sword = 'SW1H17'
        Sword_of_Balduran = 'SW1H18'
        The_Vampires_Revenge = 'SW1H19'
        Scimitar_1 = 'SW1H20'
        Short_Sword_1 = 'SW1H21'
        Scimitar_PLUS1 = 'SW1H22'
        Scimitar_PLUS2 = 'SW1H23'
        Long_Sword_PLUS1_Flame_Tongue = 'SW1H24'
        Kundane_PLUS2_Sword_of_Quickness = 'SW1H25'
        Ilbratha_Short_Sword_PLUS_1 = 'SW1H26'
        Arbanes_Sword_PLUS2 = 'SW1H27'
        Cutthroat_PLUS4 = 'SW1H28'
        Short_Sword_PLUS2_1 = 'SW1H29'
        Scimitar_of_Speed_PLUS2_Belm = 'SW1H30'
        Sunblade_Daystar = 'SW1H31'
        Long_sword_PLUS2__Dragonslayer = 'SW1H32'
        Long_Sword_PLUS2_Ras_The_Dancing_Blade = 'SW1H33'
        Bastard_Sword_PLUS1_Albruin = 'SW1H34'
        Adjatha_the_Drinker_Long_Sword_PLUS2 = 'SW1H35'
        Namarra_Long_Sword_PLUS2 = 'SW1H36'
        Taragarth_the_Bloodbrand_Bastard_Sword_PLUS1 = 'SW1H37'
        Jhor_the_Bleeder_Bastard_Sword_PLUS2 = 'SW1H38'
        Blade_of_Searing_Bastard_Sword_PLUS3 = 'SW1H39'
        Blade_of_Roses_Long_Sword_PLUS3 = 'SW1H40'
        Long_Sword_PLUS2_1 = 'SW1H41'
        Bastard_Sword_PLUS2 = 'SW1H42'
        Katana = 'SW1H43'
        Katana_PLUS1 = 'SW1H44'
        Katana_PLUS2_Malakar = 'SW1H45'
        Wakizashi = 'SW1H46'
        Wakizashi_PLUS1 = 'SW1H47'
        NinjaTo = 'SW1H48'
        NinjaTo_PLUS1 = 'SW1H49'
        Scimitar_PLUS1_Shazzellim = 'SW1H50'
        Celestial_Fury_Katana_PLUS3 = 'SW1H51'
        Scimitar_PLUS3_Waters_Edge = 'SW1H52'
        Sword_of_Flame_PLUS1 = 'SW1H53'
        Long_Sword_The_Equalizer = 'SW1H54'
        Pieces_of_the_Equalizer = 'SW1H54A, SW1H54B, SW1H54C'
        Katana_PLUS2 = 'SW1H55'
        Scimitar_2 = 'SW1H56'
        Short_Sword_of_Mask_PLUS4 = 'SW1H58'
        Short_Sword_of_Mask_PLUS5 = 'SW1H59'
        Angurvadal_PLUS4 = 'SW1H60'
        Angurvadal_PLUS5 = 'SW1H61'
        Foebane_PLUS3 = 'SW1H62'
        Foebane_PLUS5 = 'SW1H63'
        Purifier_PLUS4 = 'SW1H64'
        Purifier_PLUS5 = 'SW1H65'
        Yamato_PLUS4 = 'SW1H66'
        Usunos_Blade_PLUS4 = 'SW1H67'
        Spectral_Brand_PLUS4 = 'SW1H68'
        Spectral_Brand_PLUS5 = 'SW1H69'
        Hindos_Doom_PLUS3 = 'SW1H70'
        Hindos_Doom_PLUS4 = 'SW1H71'
        Bastard_Sword_PLUS3 = 'SW1H72'
        Long_Sword_PLUS3 = 'SW1H73'
        Short_Sword_PLUS3 = 'SW1H74'
        Katana_PLUS3 = 'SW1H75'
        Scimitar_PLUS3 = 'SW1H76'
        The_Answerer_PLUS4 = 'SW1H77'
        Sword_of_Arvoreen = 'NPSW01'
        Katana_PLUS1_1 = 'NPSW02'
        Hallowed_Redeemer_PLUS2 = 'NPSW03'
        Corthala_Family_Blade_PLUS2 = 'NPSW04'
        Entropy = 'NPSW05'
        Chaos_Blade = 'NPSW06'
        Sensate_Amulet = 'WA2AMU'
        Dakkons_Zerth_Blade = 'WA2DAK'
        Harmonium_Halberd = 'WA2HALB'
        Harp_of_Pandemonium = 'WA2HARP'
        Vhailors_Helm = 'WA2HELM'
        Plate_of_Balduran = 'WA2PLAT'
        Mercykiller_Ring = 'WA2RING'
        Robe_of_Vecna = 'WA2ROBE'
        Sword_of_Balduran_1 = 'WA2S1H'
        Shield_of_Balduran = 'WA2SHIEL'

    class TWO_HANDED_SWORDS(Enum):

        Two_Handed_Sword = 'SW2H01'
        Two_Handed_Sword_PLUS1 = 'SW2H02'
        Two_Handed_Sword_Berserking = 'SW2H03'
        Two_Handed_Sword_1 = 'SW2H05'
        Spiders_Bane = 'SW2H06'
        Two_Handed_Sword_PLUS3 = 'SW2H07'
        Two_Handed_sword_PLUS2 = 'SW2H08'
        Two_Handed_Sword_PLUS4_Warblade = 'SW2H09'
        Holy_Avenger = 'SW2H10'
        Two_Handed_Sword_PLUS2 = 'SW2H11'
        Two_Handed_Sword_Flame_of_the_North_PLUS_2 = 'SW2H12'
        Spiders_Bane_PLUS_2 = 'SW2H13'
        Lilarcor = 'SW2H14'
        Silver_Sword = 'SW2H15'
        Silver_Hilt = 'SW2H15A'
        Sword_of_Chaos_PLUS2 = 'SW2H16'
        Gram_the_Sword_of_Grief_PLUS5 = 'SW2H17'
        Gram_the_Sword_of_Grief_PLUS5_1 = 'SW2H18'
        Carsomyr_PLUS6 = 'SW2H19'
        Two_Handed_Sword_PLUS3_1 = 'SW2H20'
        Psions_Blade_PLUS5 = 'SW2H21'
        Cursed_Berserking_Sword_PLUS3 = 'SW2H99'
        Soul_Reaver_PLUS4 = 'SW2HDEAT'

    class WANDS(Enum):

        Wand_of_Fear = 'WAND02'
        Wand_of_Magic_Missiles = 'WAND03'
        Wand_of_Paralyzation = 'WAND04'
        Wand_of_Fire = 'WAND05'
        Wand_of_Frost = 'WAND06'
        Wand_of_Lightning_1 = 'WAND07'
        Wand_of_Sleep = 'WAND08'
        Wand_of_Polymorphing = 'WAND09'
        Wand_of_Monster_Summoning = 'WAND10'
        Wand_of_the_Heavens = 'WAND11'
        Wand_of_Wonder = 'WAND12'
        Wand_of_Cloudkill = 'WAND13'
        Web_Sack = 'WAND14'
        Wand_of_Apprenti = 'WAND15'
        Potion_of_Icedust = 'WAND16'
        Wand_of_Spell_Striking = 'WAND18'
        Wand_of_Cursing = 'WAND19'

# %%
print('class Items:')
names = dict()
for i in s.split('\n'):
    if not i or len(i) < 3:
        continue
    _i = re.search('([a-zA-Z0-9 ]+):', i)
    _i2 = re.search(' - ', i)
    if _i and not _i2:
        print()
        print('    class %s(Enum):' %re.sub(' ', '_', _i.group(1).strip()))
        print()
        continue
    _i = re.split(' - ', i)
    if len(_i) == 2:
        _name = re.search('[a-zA-Z0-9+-:\'\(\) ]+(\+\d)?', _i[1]).group(0).strip()
        _name = re.sub(r'\(.*\)', '', _name)
        _name = _name.replace('+', 'PLUS')
        _name = re.sub('[^a-zA-Z0-9 ]', '', _name)
        _name = _name.strip().replace(' ', '_')
        if _name in names.keys():
            names[_name] += 1
            _name = _name + '_' + str(names[_name]) 
        else:
            names[_name] = 0
        _index = _i[0].strip()
        if not re.match('\w+(\d+)?', _index):
            _r = '# '
        else:
            _r = ''
        print("        %s%s = '%s'" %(_r, _name, _i[0].strip()))

# %%
import pandas as pd
import re
item_file = 'allitem.txt'
with open(item_file, 'r') as _source:
    items = _source.read()
with open(item_file, 'r') as _source:
    items1 = _source.readlines()

# %%
df = pd.DataFrame()
_pattern = re.compile(r'(?P<type>.*)\t(?P<name>.*)\t(?P<code>.*)\t(?P<description>.*?)')

# %%
_items = list(re.finditer(_pattern, items.replace('.', '\n')))

# %%
df = pd.DataFrame([_.groupdict() for _ in _items])

# %%
import pandas as pd

# %%
df = pd.read_csv('items.csv')

def repeats(s):
    s = list(s)
    _d = dict()
    for index, item in enumerate(s):
        if item in _d.keys():
            s[index] = s[index] + '_' + str(_d[item])
            _d[item] += 1
        else:
            _d[item] = 1
    return s

def rename(s):
    s = s.replace("'s", 's').replace("'S", 'S')
    s = s.replace('+', 'PLUS')
    s = re.sub('[^a-zA-Z0-9]', '_', s)
    return s

df['id'] = repeats(df['Name'].apply(rename))

# %%
df1 = df[~df['Name'].str.contains('<No Name>')]
df2 = df1[~((df1['Generic Description'] == 'No Description') & (df1['Identified Description'] == 'No Description'))]
df2 = df2.sort_values(['Type', 'Generic Description', 'Resource', ])

# %%
grouped = df2.groupby(['Type', 'Generic Description'])

# %%
with open('itemgroup.txt', 'w') as _t:
    for group in grouped:
        for _row in group[1].sort_values('Resource').iterrows():
            _t.write("    %s = '%s'\n" %(_row[1].id, _row[1].Resource))
        _t.write('\n')

# %%
df2[100:200]
# Out:
#        Type                          Name  Resource  \
# 1812  Armor             Plate of Balduran   WA2PLAT
# 1259  Armor                    Hide Armor   DLEAT10
# 1260  Armor                    Hide Armor    LEAT10
# 173   Armor               Aeger's Hide +3    LEAT20
# 1261  Armor                 Hide Armor +1  OHLEAT50
# 1262  Armor                 Hide Armor +2  OHLEAT51
# 1263  Armor                 Hide Armor +3  OHLEAT52
# 465   Armor                Big Metal Unit  SECRET05
# 1402  Armor          Jansen AdventureWear     NPARM
# 704   Armor         Corthala Family Armor    NPCHAN
# 2270  Armor           Silver Dragon Scale  OHDARMOR
# 203   Armor             Ankheg Plate Mail    PLAT06
# 1964  Armor              Red Dragon Scale    PLAT18
# 1801  Armor                    Plate Mail   IPLAT01
# 1802  Armor                    Plate Mail    MISC99
# 1811  Armor                 Plate Mail +2  OHPLAT50
# 1803  Armor                    Plate Mail    PLAT01
# ...
